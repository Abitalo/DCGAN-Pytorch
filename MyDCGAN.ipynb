# %%
import xml.etree.cElementTree as ET
import numpy as np
from pathlib import Path
from PIL import Image
import cv2
from DCGAN_dog import NetG, NetD
import config
import gzip
import pickle

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from torch.utils.data import DataLoader, TensorDataset

# %%
device = torch.device('cuda:2' if torch.cuda.is_available else 'cpu')
BATCH_SIZE = config.BATCH_SIZE
MAX_EPOCH = 300
latent_dim = config.latent_dim

# %%
data_root = Path('stanford_dog/')
annotation_path = data_root / 'annotation'
image_path = data_root / 'images'
croped_path = data_root / 'croped_images'
croped_path.mkdir(parents = True, exist_ok = True)
processed_path = data_root / 'processed'
processed_path.mkdir(parents = True, exist_ok = True)

# %%
# 根据annotation里的bounding box得到crop后的图片
# for category_dir in annotation_path.iterdir():
#     (croped_path / category_dir.name).mkdir(parents=True, exist_ok=True)
#     for i in category_dir.iterdir():
#         root = ET.parse(str(i)).getroot()
#         x_min = int(root[5][4][0].text)
#         y_min = int(root[5][4][1].text)
#         x_max = int(root[5][4][2].text)
#         y_max = int(root[5][4][3].text)
#         img = cv2.imread(str(image_path / category_dir.name / i.stem) + '.jpg', -1)
#         cv2.imwrite(str(croped_path / category_dir.name / i.stem) + '.jpg', img[int(y_min):int(y_max), int(x_min):int(x_max),:])

# %%
# 将crop后的图片缩放的109*109*3以匹配输入
# for category_dir in croped_path.iterdir():
#     (processed_path / category_dir.name).mkdir(parents=True, exist_ok=True)
#     for i in category_dir.iterdir():
#         img = cv2.imread(str(i), -1)
#         img = cv2.resize(img,(109,109), interpolation = cv2.INTER_AREA)
#         cv2.imwrite(str(processed_path / category_dir.name / i.name), img)

# %%
ds_train = torchvision.datasets.ImageFolder('data/', transform=torchvision.transforms.Compose([
    torchvision.transforms.Resize((109,109)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean = (0.4211971, 0.40016708, 0.40234432), std=(0.27824208, 0.27396, 0.27874818))
]))

dl_train = DataLoader(
    dataset=ds_train,
    batch_size=BATCH_SIZE,
    shuffle=True,    
#     num_workers=2,
    drop_last=True
)

# %%
def model_init():
    G, D = NetG().to(device), NetD().to(device)
    # Adam 修改一下Momentum的参数，0.5等于focus on最近的2次迭代，默认的beta1 = 0.9，focus on最近10次有点太长了。
    optG = torch.optim.SGD(G.parameters(), lr=0.00002)# 一开始用lr=0.0002会好一点
    optD = torch.optim.SGD(D.parameters(), lr=0.00002)
#     optD = torch.optim.SGD(D.parameters(), lr=0.0002)
    return G, optG, D, optD

# %%
real_labels = torch.ones(BATCH_SIZE, 1).to(device)
fake_labels = -1.0 * torch.ones(BATCH_SIZE, 1).to(device)
g_labels = torch.ones(BATCH_SIZE, 1).to(device)
def fit(G, D, optG, optD, criterion, start_epoch = 0, max_epoch = MAX_EPOCH):
    for epoch in range(start_epoch, max_epoch):
        for i, (x_gt, y_gt) in enumerate(dl_train):
            # 将x,y转好格式
            x_gt = x_gt.to(device) # (1024,784)float32
#             y_gt = F.one_hot(y_gt.to(torch.long)).to(device) # (batch_size,10) float32,因为输入要cat，与z保持同类型
            
            # 固定G，训练D
#             G.eval()
#             D.train()              
            # 生成Gaussian噪声
            z = torch.randn((BATCH_SIZE, latent_dim)).view(BATCH_SIZE, latent_dim, 1, 1).to(device) # (batch_size,100) float32
   
            out_x = D(x_gt)
            loss_x = criterion(out_x, real_labels)  
        
            out_z = D(G(z).detach()) # (batch_size,1) float32 detach防止误差传播到G
            loss_z = criterion(out_z, fake_labels)
            loss_D = loss_z + loss_x
            
            optD.zero_grad()
            loss_D.backward()
            optD.step()
            
            # 固定G，训练D
            if i % 2 == 0:        
#                 G.train()
#                 D.eval()
                # 生成Gaussian噪声
                z = torch.randn(BATCH_SIZE, latent_dim).view(BATCH_SIZE, latent_dim, 1, 1).to(device) # (1024,100) float32
                fake = G(z)
                out_z = D(fake) # (1024,1) float32
                loss_G = criterion(out_z, g_labels)

                optG.zero_grad()
                loss_G.backward()
                optG.step()
                
                print('Epoch:[%d/%d], Iteration:[%d/%d], Loss_G = %f, Loss_D = %f.\n' %(epoch+1, max_epoch, i, (8144//BATCH_SIZE), loss_G.item(), loss_D.item()))

        
        
        if (epoch+1) % 1 == 0:
#             G.eval()
            print('Epoch:[%d/%d], Loss_G = %f, Loss_D = %f.\n' %(epoch+1, max_epoch, loss_G.item(), loss_D.item()))
#             img = get_sample_image(G)
            torchvision.utils.save_image(fake, 'DCGAN_sampler/%d_my.jpg' % (epoch+1))
#             cv2.imwrite('DCGAN_sampler/%d.jpg' % (epoch+1), img*255)

# %%
# criterion = F.mse_loss #predict使用onehot过的标签作为输入，但是计算损失还是只考虑是否为数字
criterion = nn.MSELoss().to(device)
G, optG, D, optD = model_init()

# %%
G.load_state_dict(torch.load('car_G_481.pth')['state'])
D.load_state_dict(torch.load('car_D_481.pth')['state'])

# %%
fit(G,D,optG,optD,criterion,1000,1500)
# Out:
# Epoch:[1001/1500], Iteration:[0/15], Loss_G = 2.227064, Loss_D = 0.311804.
#
# Epoch:[1001/1500], Iteration:[2/15], Loss_G = 2.410249, Loss_D = 0.331204.
#
# Epoch:[1001/1500], Iteration:[4/15], Loss_G = 2.504159, Loss_D = 0.285710.
#
# Epoch:[1001/1500], Iteration:[6/15], Loss_G = 2.472982, Loss_D = 0.239517.
#
# Epoch:[1001/1500], Iteration:[8/15], Loss_G = 2.571881, Loss_D = 0.176914.
#
# Epoch:[1001/1500], Iteration:[10/15], Loss_G = 2.708025, Loss_D = 0.180518.
#
# Epoch:[1001/1500], Iteration:[12/15], Loss_G = 2.705430, Loss_D = 0.125228.
#
# Epoch:[1001/1500], Iteration:[14/15], Loss_G = 2.928019, Loss_D = 0.123685.
#
# Epoch:[1001/1500], Loss_G = 2.928019, Loss_D = 0.123685.
#
# Epoch:[1002/1500], Iteration:[0/15], Loss_G = 2.939899, Loss_D = 0.133797.
#
# Epoch:[1002/1500], Iteration:[2/15], Loss_G = 3.026256, Loss_D = 0.102908.
#
# Epoch:[1002/1500], Iteration:[4/15], Loss_G = 3.078828, Loss_D = 0.083937.
#
# Epoch:[1002/1500], Iteration:[6/15], Loss_G = 3.163186, Loss_D = 0.107242.
#
# Epoch:[1002/1500], Iteration:[8/15], Loss_G = 3.039152, Loss_D = 0.073319.
#
# Epoch:[1002/1500], Iteration:[10/15], Loss_G = 3.215453, Loss_D = 0.055170.
#
# Epoch:[1002/1500], Iteration:[12/15], Loss_G = 3.187548, Loss_D = 0.062638.
#
# Epoch:[1002/1500], Iteration:[14/15], Loss_G = 3.153942, Loss_D = 0.059498.
#
# Epoch:[1002/1500], Loss_G = 3.153942, Loss_D = 0.059498.
#
# Epoch:[1003/1500], Iteration:[0/15], Loss_G = 3.261483, Loss_D = 0.063498.
#
# Epoch:[1003/1500], Iteration:[2/15], Loss_G = 3.306391, Loss_D = 0.063001.
#
# Epoch:[1003/1500], Iteration:[4/15], Loss_G = 3.382884, Loss_D = 0.045209.
#
# Epoch:[1003/1500], Iteration:[6/15], Loss_G = 3.456219, Loss_D = 0.038434.
#
# Epoch:[1003/1500], Iteration:[8/15], Loss_G = 3.531211, Loss_D = 0.028898.
#
# Epoch:[1003/1500], Iteration:[10/15], Loss_G = 3.477894, Loss_D = 0.038275.
#
# Epoch:[1003/1500], Iteration:[12/15], Loss_G = 3.450118, Loss_D = 0.037328.
#
# Epoch:[1003/1500], Iteration:[14/15], Loss_G = 3.618428, Loss_D = 0.027129.
#
# Epoch:[1003/1500], Loss_G = 3.618428, Loss_D = 0.027129.
#
# Epoch:[1004/1500], Iteration:[0/15], Loss_G = 3.540377, Loss_D = 0.033956.
#
# Epoch:[1004/1500], Iteration:[2/15], Loss_G = 3.637860, Loss_D = 0.034306.
#
# Epoch:[1004/1500], Iteration:[4/15], Loss_G = 3.641681, Loss_D = 0.026508.
#
# Epoch:[1004/1500], Iteration:[6/15], Loss_G = 3.666410, Loss_D = 0.019260.
#
# Epoch:[1004/1500], Iteration:[8/15], Loss_G = 3.748560, Loss_D = 0.028073.
#
# Epoch:[1004/1500], Iteration:[10/15], Loss_G = 3.694249, Loss_D = 0.025007.
#
# Epoch:[1004/1500], Iteration:[12/15], Loss_G = 3.724205, Loss_D = 0.025762.
#
# Epoch:[1004/1500], Iteration:[14/15], Loss_G = 3.787380, Loss_D = 0.021436.
#
# Epoch:[1004/1500], Loss_G = 3.787380, Loss_D = 0.021436.
#
# Epoch:[1005/1500], Iteration:[0/15], Loss_G = 3.712974, Loss_D = 0.023642.
#
# Epoch:[1005/1500], Iteration:[2/15], Loss_G = 3.778000, Loss_D = 0.017331.
#
# Epoch:[1005/1500], Iteration:[4/15], Loss_G = 3.810943, Loss_D = 0.019016.
#
# Epoch:[1005/1500], Iteration:[6/15], Loss_G = 3.757630, Loss_D = 0.026313.
#
# Epoch:[1005/1500], Iteration:[8/15], Loss_G = 3.700939, Loss_D = 0.022926.
#
# Epoch:[1005/1500], Iteration:[10/15], Loss_G = 3.763816, Loss_D = 0.017730.
#
# Epoch:[1005/1500], Iteration:[12/15], Loss_G = 3.891451, Loss_D = 0.018342.
#
# Epoch:[1005/1500], Iteration:[14/15], Loss_G = 3.820572, Loss_D = 0.017360.
#
# Epoch:[1005/1500], Loss_G = 3.820572, Loss_D = 0.017360.
#
# Epoch:[1006/1500], Iteration:[0/15], Loss_G = 3.722329, Loss_D = 0.016865.
#
# Epoch:[1006/1500], Iteration:[2/15], Loss_G = 3.813564, Loss_D = 0.015198.
#
# Epoch:[1006/1500], Iteration:[4/15], Loss_G = 3.690694, Loss_D = 0.021440.
#
# Epoch:[1006/1500], Iteration:[6/15], Loss_G = 3.853374, Loss_D = 0.024847.
#
# Epoch:[1006/1500], Iteration:[8/15], Loss_G = 3.886683, Loss_D = 0.014163.
#
# Epoch:[1006/1500], Iteration:[10/15], Loss_G = 3.917391, Loss_D = 0.014206.
#
# Epoch:[1006/1500], Iteration:[12/15], Loss_G = 3.804231, Loss_D = 0.013495.
#
# Epoch:[1006/1500], Iteration:[14/15], Loss_G = 3.976818, Loss_D = 0.018807.
#
# Epoch:[1006/1500], Loss_G = 3.976818, Loss_D = 0.018807.
#
# Epoch:[1007/1500], Iteration:[0/15], Loss_G = 3.812418, Loss_D = 0.016143.
#
# Epoch:[1007/1500], Iteration:[2/15], Loss_G = 3.867867, Loss_D = 0.015496.
#
# Epoch:[1007/1500], Iteration:[4/15], Loss_G = 3.892090, Loss_D = 0.021671.
#
# Epoch:[1007/1500], Iteration:[6/15], Loss_G = 3.887216, Loss_D = 0.013128.
#
# Epoch:[1007/1500], Iteration:[8/15], Loss_G = 3.927532, Loss_D = 0.014386.
#
# Epoch:[1007/1500], Iteration:[10/15], Loss_G = 3.803963, Loss_D = 0.016344.
#
# Epoch:[1007/1500], Iteration:[12/15], Loss_G = 3.918264, Loss_D = 0.017811.
#
# Epoch:[1007/1500], Iteration:[14/15], Loss_G = 3.887641, Loss_D = 0.015160.
#
# Epoch:[1007/1500], Loss_G = 3.887641, Loss_D = 0.015160.
#
# Epoch:[1008/1500], Iteration:[0/15], Loss_G = 3.908668, Loss_D = 0.015851.
#
# Epoch:[1008/1500], Iteration:[2/15], Loss_G = 3.780317, Loss_D = 0.013593.
#
# Epoch:[1008/1500], Iteration:[4/15], Loss_G = 3.967671, Loss_D = 0.012960.
#
# Epoch:[1008/1500], Iteration:[6/15], Loss_G = 3.950205, Loss_D = 0.015569.
#
# Epoch:[1008/1500], Iteration:[8/15], Loss_G = 3.932539, Loss_D = 0.014283.
#
# Epoch:[1008/1500], Iteration:[10/15], Loss_G = 3.833452, Loss_D = 0.019221.
#
# Epoch:[1008/1500], Iteration:[12/15], Loss_G = 3.899639, Loss_D = 0.018357.
#
# Epoch:[1008/1500], Iteration:[14/15], Loss_G = 3.946569, Loss_D = 0.018143.
#
# Epoch:[1008/1500], Loss_G = 3.946569, Loss_D = 0.018143.
#
# Epoch:[1009/1500], Iteration:[0/15], Loss_G = 3.908057, Loss_D = 0.013484.
#
# Epoch:[1009/1500], Iteration:[2/15], Loss_G = 3.922551, Loss_D = 0.015979.
#
# Epoch:[1009/1500], Iteration:[4/15], Loss_G = 3.849053, Loss_D = 0.015649.
#
# Epoch:[1009/1500], Iteration:[6/15], Loss_G = 3.824052, Loss_D = 0.016892.
#
# Epoch:[1009/1500], Iteration:[8/15], Loss_G = 3.867820, Loss_D = 0.016357.
#
# Epoch:[1009/1500], Iteration:[10/15], Loss_G = 3.983568, Loss_D = 0.017675.
#
# Epoch:[1009/1500], Iteration:[12/15], Loss_G = 3.996566, Loss_D = 0.016523.
#
# Epoch:[1009/1500], Iteration:[14/15], Loss_G = 3.781628, Loss_D = 0.014530.
#
# Epoch:[1009/1500], Loss_G = 3.781628, Loss_D = 0.014530.
#
# Epoch:[1010/1500], Iteration:[0/15], Loss_G = 3.892347, Loss_D = 0.012554.
#
# Epoch:[1010/1500], Iteration:[2/15], Loss_G = 4.017782, Loss_D = 0.017788.
#
# Epoch:[1010/1500], Iteration:[4/15], Loss_G = 3.839424, Loss_D = 0.015260.
#
# Epoch:[1010/1500], Iteration:[6/15], Loss_G = 3.973379, Loss_D = 0.016765.
#
# Epoch:[1010/1500], Iteration:[8/15], Loss_G = 3.841054, Loss_D = 0.017513.
#
# Epoch:[1010/1500], Iteration:[10/15], Loss_G = 4.092756, Loss_D = 0.012943.
#
# Epoch:[1010/1500], Iteration:[12/15], Loss_G = 3.990154, Loss_D = 0.012126.
#
# Epoch:[1010/1500], Iteration:[14/15], Loss_G = 3.964739, Loss_D = 0.012439.
#
# Epoch:[1010/1500], Loss_G = 3.964739, Loss_D = 0.012439.
#
# Epoch:[1011/1500], Iteration:[0/15], Loss_G = 3.855006, Loss_D = 0.013907.
#
# Epoch:[1011/1500], Iteration:[2/15], Loss_G = 3.903145, Loss_D = 0.015088.
#
# Epoch:[1011/1500], Iteration:[4/15], Loss_G = 3.799402, Loss_D = 0.012297.
#
# Epoch:[1011/1500], Iteration:[6/15], Loss_G = 3.962092, Loss_D = 0.012642.
#
# Epoch:[1011/1500], Iteration:[8/15], Loss_G = 3.920610, Loss_D = 0.011675.
#
# Epoch:[1011/1500], Iteration:[10/15], Loss_G = 3.897390, Loss_D = 0.013300.
#
# Epoch:[1011/1500], Iteration:[12/15], Loss_G = 3.740963, Loss_D = 0.013172.
#
# Epoch:[1011/1500], Iteration:[14/15], Loss_G = 3.961161, Loss_D = 0.016197.
#
# Epoch:[1011/1500], Loss_G = 3.961161, Loss_D = 0.016197.
#
# Epoch:[1012/1500], Iteration:[0/15], Loss_G = 3.875657, Loss_D = 0.015773.
#
# Epoch:[1012/1500], Iteration:[2/15], Loss_G = 3.929048, Loss_D = 0.026721.
#
# Epoch:[1012/1500], Iteration:[4/15], Loss_G = 3.903153, Loss_D = 0.012690.
#
# Epoch:[1012/1500], Iteration:[6/15], Loss_G = 3.868386, Loss_D = 0.012841.
#
# Epoch:[1012/1500], Iteration:[8/15], Loss_G = 3.935920, Loss_D = 0.014457.
#
# Epoch:[1012/1500], Iteration:[10/15], Loss_G = 3.989968, Loss_D = 0.012537.
#
# Epoch:[1012/1500], Iteration:[12/15], Loss_G = 3.974250, Loss_D = 0.017029.
#
# Epoch:[1012/1500], Iteration:[14/15], Loss_G = 3.964461, Loss_D = 0.013410.
#
# Epoch:[1012/1500], Loss_G = 3.964461, Loss_D = 0.013410.
#
# Epoch:[1013/1500], Iteration:[0/15], Loss_G = 3.878488, Loss_D = 0.016752.
#
# Epoch:[1013/1500], Iteration:[2/15], Loss_G = 3.947307, Loss_D = 0.014124.
#
# Epoch:[1013/1500], Iteration:[4/15], Loss_G = 4.015811, Loss_D = 0.011397.
#
# Epoch:[1013/1500], Iteration:[6/15], Loss_G = 3.994342, Loss_D = 0.016689.
#
# Epoch:[1013/1500], Iteration:[8/15], Loss_G = 3.914031, Loss_D = 0.018038.
#
# Epoch:[1013/1500], Iteration:[10/15], Loss_G = 3.953883, Loss_D = 0.015960.
#
# Epoch:[1013/1500], Iteration:[12/15], Loss_G = 3.925806, Loss_D = 0.013013.
#
# Epoch:[1013/1500], Iteration:[14/15], Loss_G = 3.938072, Loss_D = 0.013524.
#
# Epoch:[1013/1500], Loss_G = 3.938072, Loss_D = 0.013524.
#
# Epoch:[1014/1500], Iteration:[0/15], Loss_G = 4.025414, Loss_D = 0.013635.
#
# Epoch:[1014/1500], Iteration:[2/15], Loss_G = 3.957341, Loss_D = 0.015373.
#
# Epoch:[1014/1500], Iteration:[4/15], Loss_G = 3.898862, Loss_D = 0.012642.
#
# Epoch:[1014/1500], Iteration:[6/15], Loss_G = 3.802850, Loss_D = 0.014674.
#
# Epoch:[1014/1500], Iteration:[8/15], Loss_G = 3.866835, Loss_D = 0.016006.
#
# Epoch:[1014/1500], Iteration:[10/15], Loss_G = 3.907938, Loss_D = 0.012779.
#
# Epoch:[1014/1500], Iteration:[12/15], Loss_G = 4.025554, Loss_D = 0.011820.
#
# Epoch:[1014/1500], Iteration:[14/15], Loss_G = 3.930542, Loss_D = 0.020106.
#
# Epoch:[1014/1500], Loss_G = 3.930542, Loss_D = 0.020106.
#
# Epoch:[1015/1500], Iteration:[0/15], Loss_G = 3.834733, Loss_D = 0.013885.
#
# Epoch:[1015/1500], Iteration:[2/15], Loss_G = 3.977392, Loss_D = 0.013442.
#
# Epoch:[1015/1500], Iteration:[4/15], Loss_G = 4.089211, Loss_D = 0.014688.
#
# Epoch:[1015/1500], Iteration:[6/15], Loss_G = 3.973468, Loss_D = 0.014223.
#
# Epoch:[1015/1500], Iteration:[8/15], Loss_G = 3.886219, Loss_D = 0.019650.
#
# Epoch:[1015/1500], Iteration:[10/15], Loss_G = 4.017492, Loss_D = 0.012432.
#
# Epoch:[1015/1500], Iteration:[12/15], Loss_G = 3.971923, Loss_D = 0.011304.
#
# Epoch:[1015/1500], Iteration:[14/15], Loss_G = 3.847513, Loss_D = 0.013454.
#
# Epoch:[1015/1500], Loss_G = 3.847513, Loss_D = 0.013454.
#
# Epoch:[1016/1500], Iteration:[0/15], Loss_G = 3.927909, Loss_D = 0.013253.
#
# Epoch:[1016/1500], Iteration:[2/15], Loss_G = 3.941667, Loss_D = 0.013202.
#
# Epoch:[1016/1500], Iteration:[4/15], Loss_G = 3.888638, Loss_D = 0.012284.
#
# Epoch:[1016/1500], Iteration:[6/15], Loss_G = 4.022997, Loss_D = 0.011974.
#
# Epoch:[1016/1500], Iteration:[8/15], Loss_G = 3.962577, Loss_D = 0.012431.
#
# Epoch:[1016/1500], Iteration:[10/15], Loss_G = 3.882456, Loss_D = 0.012395.
#
# Epoch:[1016/1500], Iteration:[12/15], Loss_G = 3.844217, Loss_D = 0.013688.
#
# Epoch:[1016/1500], Iteration:[14/15], Loss_G = 3.943497, Loss_D = 0.012132.
#
# Epoch:[1016/1500], Loss_G = 3.943497, Loss_D = 0.012132.
#
# Epoch:[1017/1500], Iteration:[0/15], Loss_G = 4.049551, Loss_D = 0.012042.
#
# Epoch:[1017/1500], Iteration:[2/15], Loss_G = 3.835612, Loss_D = 0.013432.
#
# Epoch:[1017/1500], Iteration:[4/15], Loss_G = 3.892509, Loss_D = 0.013693.
#
# Epoch:[1017/1500], Iteration:[6/15], Loss_G = 3.835829, Loss_D = 0.013614.
#
# Epoch:[1017/1500], Iteration:[8/15], Loss_G = 4.019779, Loss_D = 0.012134.
#
# Epoch:[1017/1500], Iteration:[10/15], Loss_G = 3.916540, Loss_D = 0.015066.
#
# Epoch:[1017/1500], Iteration:[12/15], Loss_G = 4.025346, Loss_D = 0.012949.
#
# Epoch:[1017/1500], Iteration:[14/15], Loss_G = 3.907555, Loss_D = 0.012894.
#
# Epoch:[1017/1500], Loss_G = 3.907555, Loss_D = 0.012894.
#
# Epoch:[1018/1500], Iteration:[0/15], Loss_G = 3.860549, Loss_D = 0.013230.
#
# Epoch:[1018/1500], Iteration:[2/15], Loss_G = 3.855663, Loss_D = 0.011704.
#
# Epoch:[1018/1500], Iteration:[4/15], Loss_G = 3.878969, Loss_D = 0.013046.
#
# Epoch:[1018/1500], Iteration:[6/15], Loss_G = 3.838491, Loss_D = 0.014862.
#
# Epoch:[1018/1500], Iteration:[8/15], Loss_G = 3.964337, Loss_D = 0.020651.
#
# Epoch:[1018/1500], Iteration:[10/15], Loss_G = 4.013547, Loss_D = 0.013658.
#
# Epoch:[1018/1500], Iteration:[12/15], Loss_G = 3.831062, Loss_D = 0.015738.
#
# Epoch:[1018/1500], Iteration:[14/15], Loss_G = 3.931514, Loss_D = 0.014103.
#
# Epoch:[1018/1500], Loss_G = 3.931514, Loss_D = 0.014103.
#
# Epoch:[1019/1500], Iteration:[0/15], Loss_G = 3.887193, Loss_D = 0.016739.
#
# Epoch:[1019/1500], Iteration:[2/15], Loss_G = 3.956258, Loss_D = 0.012215.
#
# Epoch:[1019/1500], Iteration:[4/15], Loss_G = 3.805517, Loss_D = 0.014330.
#
# Epoch:[1019/1500], Iteration:[6/15], Loss_G = 3.948248, Loss_D = 0.012166.
#
# Epoch:[1019/1500], Iteration:[8/15], Loss_G = 4.022305, Loss_D = 0.011169.
#
# Epoch:[1019/1500], Iteration:[10/15], Loss_G = 3.947954, Loss_D = 0.013862.
#
# Epoch:[1019/1500], Iteration:[12/15], Loss_G = 4.062533, Loss_D = 0.012861.
#
# Epoch:[1019/1500], Iteration:[14/15], Loss_G = 3.884931, Loss_D = 0.013312.
#
# Epoch:[1019/1500], Loss_G = 3.884931, Loss_D = 0.013312.
#
# Epoch:[1020/1500], Iteration:[0/15], Loss_G = 3.969009, Loss_D = 0.019224.
#
# Epoch:[1020/1500], Iteration:[2/15], Loss_G = 3.919766, Loss_D = 0.013232.
#
# Epoch:[1020/1500], Iteration:[4/15], Loss_G = 3.913587, Loss_D = 0.012591.
#
# Epoch:[1020/1500], Iteration:[6/15], Loss_G = 3.921374, Loss_D = 0.018289.
#
# Epoch:[1020/1500], Iteration:[8/15], Loss_G = 3.922267, Loss_D = 0.012742.
#
# Epoch:[1020/1500], Iteration:[10/15], Loss_G = 4.074491, Loss_D = 0.012307.
#
# Epoch:[1020/1500], Iteration:[12/15], Loss_G = 3.975209, Loss_D = 0.011984.
#
# Epoch:[1020/1500], Iteration:[14/15], Loss_G = 3.902180, Loss_D = 0.012190.
#
# Epoch:[1020/1500], Loss_G = 3.902180, Loss_D = 0.012190.
#
# Epoch:[1021/1500], Iteration:[0/15], Loss_G = 3.985925, Loss_D = 0.011632.
#
# Epoch:[1021/1500], Iteration:[2/15], Loss_G = 3.893197, Loss_D = 0.013348.
#
# Epoch:[1021/1500], Iteration:[4/15], Loss_G = 3.922655, Loss_D = 0.014222.
#
# Epoch:[1021/1500], Iteration:[6/15], Loss_G = 3.964688, Loss_D = 0.012504.
#
# Epoch:[1021/1500], Iteration:[8/15], Loss_G = 3.841688, Loss_D = 0.014479.
#
# Epoch:[1021/1500], Iteration:[10/15], Loss_G = 3.954480, Loss_D = 0.012230.
#
# Epoch:[1021/1500], Iteration:[12/15], Loss_G = 4.006256, Loss_D = 0.012984.
#
# Epoch:[1021/1500], Iteration:[14/15], Loss_G = 3.955411, Loss_D = 0.011143.
#
# Epoch:[1021/1500], Loss_G = 3.955411, Loss_D = 0.011143.
#
# Epoch:[1022/1500], Iteration:[0/15], Loss_G = 3.954357, Loss_D = 0.013454.
#
# Epoch:[1022/1500], Iteration:[2/15], Loss_G = 3.933528, Loss_D = 0.014847.
#
# Epoch:[1022/1500], Iteration:[4/15], Loss_G = 3.997766, Loss_D = 0.013197.
#
# Epoch:[1022/1500], Iteration:[6/15], Loss_G = 4.028338, Loss_D = 0.015373.
#
# Epoch:[1022/1500], Iteration:[8/15], Loss_G = 4.017627, Loss_D = 0.015279.
#
# Epoch:[1022/1500], Iteration:[10/15], Loss_G = 4.024083, Loss_D = 0.012750.
#
# Epoch:[1022/1500], Iteration:[12/15], Loss_G = 3.964832, Loss_D = 0.013457.
#
# Epoch:[1022/1500], Iteration:[14/15], Loss_G = 3.948744, Loss_D = 0.013334.
#
# Epoch:[1022/1500], Loss_G = 3.948744, Loss_D = 0.013334.
#
# Epoch:[1023/1500], Iteration:[0/15], Loss_G = 3.970655, Loss_D = 0.013512.
#
# Epoch:[1023/1500], Iteration:[2/15], Loss_G = 3.877578, Loss_D = 0.012142.
#
# Epoch:[1023/1500], Iteration:[4/15], Loss_G = 3.931528, Loss_D = 0.015137.
#
# Epoch:[1023/1500], Iteration:[6/15], Loss_G = 4.019046, Loss_D = 0.009869.
#
# Epoch:[1023/1500], Iteration:[8/15], Loss_G = 3.928083, Loss_D = 0.012198.
#
# Epoch:[1023/1500], Iteration:[10/15], Loss_G = 3.937062, Loss_D = 0.013256.
#
# Epoch:[1023/1500], Iteration:[12/15], Loss_G = 3.948617, Loss_D = 0.011927.
#
# Epoch:[1023/1500], Iteration:[14/15], Loss_G = 3.860357, Loss_D = 0.015639.
#
# Epoch:[1023/1500], Loss_G = 3.860357, Loss_D = 0.015639.
#
# Epoch:[1024/1500], Iteration:[0/15], Loss_G = 3.953981, Loss_D = 0.014777.
#
# Epoch:[1024/1500], Iteration:[2/15], Loss_G = 3.984549, Loss_D = 0.013026.
#
# Epoch:[1024/1500], Iteration:[4/15], Loss_G = 3.977705, Loss_D = 0.010218.
#
# Epoch:[1024/1500], Iteration:[6/15], Loss_G = 3.865095, Loss_D = 0.012411.
#
# Epoch:[1024/1500], Iteration:[8/15], Loss_G = 3.988023, Loss_D = 0.012922.
#
# Epoch:[1024/1500], Iteration:[10/15], Loss_G = 3.936996, Loss_D = 0.012977.
#
# Epoch:[1024/1500], Iteration:[12/15], Loss_G = 3.963721, Loss_D = 0.012461.
#
# Epoch:[1024/1500], Iteration:[14/15], Loss_G = 3.941262, Loss_D = 0.012694.
#
# Epoch:[1024/1500], Loss_G = 3.941262, Loss_D = 0.012694.
#
# Epoch:[1025/1500], Iteration:[0/15], Loss_G = 3.876626, Loss_D = 0.013993.
#
# Epoch:[1025/1500], Iteration:[2/15], Loss_G = 3.901864, Loss_D = 0.014191.
#
# Epoch:[1025/1500], Iteration:[4/15], Loss_G = 4.004230, Loss_D = 0.014498.
#
# Epoch:[1025/1500], Iteration:[6/15], Loss_G = 3.962045, Loss_D = 0.012715.
#
# Epoch:[1025/1500], Iteration:[8/15], Loss_G = 3.947236, Loss_D = 0.013268.
#
# Epoch:[1025/1500], Iteration:[10/15], Loss_G = 3.985205, Loss_D = 0.012016.
#
# Epoch:[1025/1500], Iteration:[12/15], Loss_G = 3.969219, Loss_D = 0.014523.
#
# Epoch:[1025/1500], Iteration:[14/15], Loss_G = 3.961170, Loss_D = 0.012244.
#
# Epoch:[1025/1500], Loss_G = 3.961170, Loss_D = 0.012244.
#
# Epoch:[1026/1500], Iteration:[0/15], Loss_G = 3.938759, Loss_D = 0.014409.
#
# Epoch:[1026/1500], Iteration:[2/15], Loss_G = 3.929007, Loss_D = 0.012112.
#
# Epoch:[1026/1500], Iteration:[4/15], Loss_G = 3.982949, Loss_D = 0.012214.
#
# Epoch:[1026/1500], Iteration:[6/15], Loss_G = 3.807890, Loss_D = 0.013007.
#
# Epoch:[1026/1500], Iteration:[8/15], Loss_G = 3.892219, Loss_D = 0.011493.
#
# Epoch:[1026/1500], Iteration:[10/15], Loss_G = 3.911427, Loss_D = 0.013465.
#
# Epoch:[1026/1500], Iteration:[12/15], Loss_G = 3.973629, Loss_D = 0.012539.
#
# Epoch:[1026/1500], Iteration:[14/15], Loss_G = 4.044652, Loss_D = 0.014809.
#
# Epoch:[1026/1500], Loss_G = 4.044652, Loss_D = 0.014809.
#
# Epoch:[1027/1500], Iteration:[0/15], Loss_G = 3.900187, Loss_D = 0.014152.
#
# Epoch:[1027/1500], Iteration:[2/15], Loss_G = 4.037020, Loss_D = 0.013959.
#
# Epoch:[1027/1500], Iteration:[4/15], Loss_G = 4.026875, Loss_D = 0.011822.
#
# Epoch:[1027/1500], Iteration:[6/15], Loss_G = 3.940312, Loss_D = 0.013117.
#
# Epoch:[1027/1500], Iteration:[8/15], Loss_G = 3.970663, Loss_D = 0.012498.
#
# Epoch:[1027/1500], Iteration:[10/15], Loss_G = 3.957118, Loss_D = 0.013084.
#
# Epoch:[1027/1500], Iteration:[12/15], Loss_G = 3.920499, Loss_D = 0.014568.
#
# Epoch:[1027/1500], Iteration:[14/15], Loss_G = 3.909629, Loss_D = 0.014448.
#
# Epoch:[1027/1500], Loss_G = 3.909629, Loss_D = 0.014448.
#
# Epoch:[1028/1500], Iteration:[0/15], Loss_G = 4.026947, Loss_D = 0.011609.
#
# Epoch:[1028/1500], Iteration:[2/15], Loss_G = 3.808634, Loss_D = 0.013264.
#
# Epoch:[1028/1500], Iteration:[4/15], Loss_G = 3.936699, Loss_D = 0.011352.
#
# Epoch:[1028/1500], Iteration:[6/15], Loss_G = 3.969472, Loss_D = 0.013651.
#
# Epoch:[1028/1500], Iteration:[8/15], Loss_G = 3.914053, Loss_D = 0.011618.
#
# Epoch:[1028/1500], Iteration:[10/15], Loss_G = 4.043359, Loss_D = 0.014097.
#
# Epoch:[1028/1500], Iteration:[12/15], Loss_G = 3.918795, Loss_D = 0.012247.
#
# Epoch:[1028/1500], Iteration:[14/15], Loss_G = 3.838541, Loss_D = 0.011354.
#
# Epoch:[1028/1500], Loss_G = 3.838541, Loss_D = 0.011354.
#
# Epoch:[1029/1500], Iteration:[0/15], Loss_G = 3.915942, Loss_D = 0.013110.
#
# Epoch:[1029/1500], Iteration:[2/15], Loss_G = 3.915451, Loss_D = 0.011926.
#
# Epoch:[1029/1500], Iteration:[4/15], Loss_G = 3.925548, Loss_D = 0.013178.
#
# Epoch:[1029/1500], Iteration:[6/15], Loss_G = 3.847503, Loss_D = 0.014131.
#
# Epoch:[1029/1500], Iteration:[8/15], Loss_G = 4.014766, Loss_D = 0.013596.
#
# Epoch:[1029/1500], Iteration:[10/15], Loss_G = 3.971937, Loss_D = 0.012211.
#
# Epoch:[1029/1500], Iteration:[12/15], Loss_G = 3.885386, Loss_D = 0.015377.
#
# Epoch:[1029/1500], Iteration:[14/15], Loss_G = 3.923525, Loss_D = 0.013095.
#
# Epoch:[1029/1500], Loss_G = 3.923525, Loss_D = 0.013095.
#
# Epoch:[1030/1500], Iteration:[0/15], Loss_G = 3.841677, Loss_D = 0.012602.
#
# Epoch:[1030/1500], Iteration:[2/15], Loss_G = 3.811209, Loss_D = 0.013678.
#
# Epoch:[1030/1500], Iteration:[4/15], Loss_G = 3.978553, Loss_D = 0.012249.
#
# Epoch:[1030/1500], Iteration:[6/15], Loss_G = 3.944761, Loss_D = 0.015922.
#
# Epoch:[1030/1500], Iteration:[8/15], Loss_G = 3.799638, Loss_D = 0.017288.
#
# Epoch:[1030/1500], Iteration:[10/15], Loss_G = 4.039429, Loss_D = 0.012437.
#
# Epoch:[1030/1500], Iteration:[12/15], Loss_G = 3.951049, Loss_D = 0.011238.
#
# Epoch:[1030/1500], Iteration:[14/15], Loss_G = 3.990912, Loss_D = 0.011103.
#
# Epoch:[1030/1500], Loss_G = 3.990912, Loss_D = 0.011103.
#
# Epoch:[1031/1500], Iteration:[0/15], Loss_G = 3.954147, Loss_D = 0.012526.
#
# Epoch:[1031/1500], Iteration:[2/15], Loss_G = 3.968687, Loss_D = 0.016216.
#
# Epoch:[1031/1500], Iteration:[4/15], Loss_G = 3.987826, Loss_D = 0.012610.
#
# Epoch:[1031/1500], Iteration:[6/15], Loss_G = 3.945279, Loss_D = 0.012424.
#
# Epoch:[1031/1500], Iteration:[8/15], Loss_G = 3.895300, Loss_D = 0.012239.
#
# Epoch:[1031/1500], Iteration:[10/15], Loss_G = 4.028513, Loss_D = 0.010984.
#
# Epoch:[1031/1500], Iteration:[12/15], Loss_G = 3.849021, Loss_D = 0.013738.
#
# Epoch:[1031/1500], Iteration:[14/15], Loss_G = 3.905178, Loss_D = 0.018100.
#
# Epoch:[1031/1500], Loss_G = 3.905178, Loss_D = 0.018100.
#
# Epoch:[1032/1500], Iteration:[0/15], Loss_G = 3.864187, Loss_D = 0.018887.
#
# Epoch:[1032/1500], Iteration:[2/15], Loss_G = 3.915212, Loss_D = 0.013661.
#
# Epoch:[1032/1500], Iteration:[4/15], Loss_G = 3.932912, Loss_D = 0.012667.
#
# Epoch:[1032/1500], Iteration:[6/15], Loss_G = 3.974560, Loss_D = 0.011944.
#
# Epoch:[1032/1500], Iteration:[8/15], Loss_G = 3.904671, Loss_D = 0.011675.
#
# Epoch:[1032/1500], Iteration:[10/15], Loss_G = 3.869950, Loss_D = 0.012901.
#
# Epoch:[1032/1500], Iteration:[12/15], Loss_G = 3.793415, Loss_D = 0.012651.
#
# Epoch:[1032/1500], Iteration:[14/15], Loss_G = 3.936382, Loss_D = 0.012036.
#
# Epoch:[1032/1500], Loss_G = 3.936382, Loss_D = 0.012036.
#
# Epoch:[1033/1500], Iteration:[0/15], Loss_G = 3.921242, Loss_D = 0.014536.
#
# Epoch:[1033/1500], Iteration:[2/15], Loss_G = 3.905289, Loss_D = 0.010789.
#
# Epoch:[1033/1500], Iteration:[4/15], Loss_G = 3.928834, Loss_D = 0.013337.
#
# Epoch:[1033/1500], Iteration:[6/15], Loss_G = 3.903681, Loss_D = 0.011443.
#
# Epoch:[1033/1500], Iteration:[8/15], Loss_G = 3.941579, Loss_D = 0.013706.
#
# Epoch:[1033/1500], Iteration:[10/15], Loss_G = 3.893348, Loss_D = 0.013148.
#
# Epoch:[1033/1500], Iteration:[12/15], Loss_G = 3.924186, Loss_D = 0.017933.
#
# Epoch:[1033/1500], Iteration:[14/15], Loss_G = 4.010076, Loss_D = 0.013119.
#
# Epoch:[1033/1500], Loss_G = 4.010076, Loss_D = 0.013119.
#
# Epoch:[1034/1500], Iteration:[0/15], Loss_G = 3.988004, Loss_D = 0.012706.
#
# Epoch:[1034/1500], Iteration:[2/15], Loss_G = 4.005851, Loss_D = 0.012062.
#
# Epoch:[1034/1500], Iteration:[4/15], Loss_G = 3.983834, Loss_D = 0.012872.
#
# Epoch:[1034/1500], Iteration:[6/15], Loss_G = 3.909999, Loss_D = 0.014433.
#
# Epoch:[1034/1500], Iteration:[8/15], Loss_G = 3.883880, Loss_D = 0.011766.
#
# Epoch:[1034/1500], Iteration:[10/15], Loss_G = 3.836541, Loss_D = 0.013410.
#
# Epoch:[1034/1500], Iteration:[12/15], Loss_G = 3.944137, Loss_D = 0.014129.
#
# Epoch:[1034/1500], Iteration:[14/15], Loss_G = 3.989613, Loss_D = 0.012490.
#
# Epoch:[1034/1500], Loss_G = 3.989613, Loss_D = 0.012490.
#
# Epoch:[1035/1500], Iteration:[0/15], Loss_G = 4.016665, Loss_D = 0.012050.
#
# Epoch:[1035/1500], Iteration:[2/15], Loss_G = 3.915746, Loss_D = 0.012122.
#
# Epoch:[1035/1500], Iteration:[4/15], Loss_G = 4.008351, Loss_D = 0.011945.
#
# Epoch:[1035/1500], Iteration:[6/15], Loss_G = 3.931205, Loss_D = 0.011912.
#
# Epoch:[1035/1500], Iteration:[8/15], Loss_G = 3.910254, Loss_D = 0.011298.
#
# Epoch:[1035/1500], Iteration:[10/15], Loss_G = 4.026251, Loss_D = 0.014705.
#
# Epoch:[1035/1500], Iteration:[12/15], Loss_G = 3.927792, Loss_D = 0.012590.
#
# Epoch:[1035/1500], Iteration:[14/15], Loss_G = 3.930702, Loss_D = 0.013327.
#
# Epoch:[1035/1500], Loss_G = 3.930702, Loss_D = 0.013327.
#
# Epoch:[1036/1500], Iteration:[0/15], Loss_G = 3.862747, Loss_D = 0.012153.
#
# Epoch:[1036/1500], Iteration:[2/15], Loss_G = 3.880644, Loss_D = 0.010828.
#
# Epoch:[1036/1500], Iteration:[4/15], Loss_G = 3.918896, Loss_D = 0.013081.
#
# Epoch:[1036/1500], Iteration:[6/15], Loss_G = 3.916168, Loss_D = 0.011521.
#
# Epoch:[1036/1500], Iteration:[8/15], Loss_G = 3.995913, Loss_D = 0.012025.
#
# Epoch:[1036/1500], Iteration:[10/15], Loss_G = 3.932152, Loss_D = 0.012575.
#
# Epoch:[1036/1500], Iteration:[12/15], Loss_G = 3.902722, Loss_D = 0.016356.
#
# Epoch:[1036/1500], Iteration:[14/15], Loss_G = 3.889355, Loss_D = 0.018558.
#
# Epoch:[1036/1500], Loss_G = 3.889355, Loss_D = 0.018558.
#
# Epoch:[1037/1500], Iteration:[0/15], Loss_G = 4.043484, Loss_D = 0.013526.
#
# Epoch:[1037/1500], Iteration:[2/15], Loss_G = 3.884730, Loss_D = 0.015500.
#
# Epoch:[1037/1500], Iteration:[4/15], Loss_G = 3.940471, Loss_D = 0.011530.
#
# Epoch:[1037/1500], Iteration:[6/15], Loss_G = 3.959702, Loss_D = 0.010540.
#
# Epoch:[1037/1500], Iteration:[8/15], Loss_G = 3.993259, Loss_D = 0.012033.
#
# Epoch:[1037/1500], Iteration:[10/15], Loss_G = 3.852803, Loss_D = 0.011992.
#
# Epoch:[1037/1500], Iteration:[12/15], Loss_G = 4.051185, Loss_D = 0.011950.
#
# Epoch:[1037/1500], Iteration:[14/15], Loss_G = 3.900228, Loss_D = 0.013350.
#
# Epoch:[1037/1500], Loss_G = 3.900228, Loss_D = 0.013350.
#
# Epoch:[1038/1500], Iteration:[0/15], Loss_G = 3.909437, Loss_D = 0.019678.
#
# Epoch:[1038/1500], Iteration:[2/15], Loss_G = 3.942363, Loss_D = 0.010863.
#
# Epoch:[1038/1500], Iteration:[4/15], Loss_G = 3.865100, Loss_D = 0.013025.
#
# Epoch:[1038/1500], Iteration:[6/15], Loss_G = 3.871268, Loss_D = 0.011626.
#
# Epoch:[1038/1500], Iteration:[8/15], Loss_G = 3.915626, Loss_D = 0.012638.
#
# Epoch:[1038/1500], Iteration:[10/15], Loss_G = 4.016168, Loss_D = 0.010847.
#
# Epoch:[1038/1500], Iteration:[12/15], Loss_G = 3.917742, Loss_D = 0.012604.
#
# Epoch:[1038/1500], Iteration:[14/15], Loss_G = 4.001789, Loss_D = 0.014226.
#
# Epoch:[1038/1500], Loss_G = 4.001789, Loss_D = 0.014226.
#
# Epoch:[1039/1500], Iteration:[0/15], Loss_G = 3.849547, Loss_D = 0.012722.
#
# Epoch:[1039/1500], Iteration:[2/15], Loss_G = 3.918103, Loss_D = 0.013278.
#
# Epoch:[1039/1500], Iteration:[4/15], Loss_G = 4.041400, Loss_D = 0.012592.
#
# Epoch:[1039/1500], Iteration:[6/15], Loss_G = 3.858461, Loss_D = 0.017385.
#
# Epoch:[1039/1500], Iteration:[8/15], Loss_G = 3.860970, Loss_D = 0.012370.
#
# Epoch:[1039/1500], Iteration:[10/15], Loss_G = 3.947591, Loss_D = 0.014353.
#
# Epoch:[1039/1500], Iteration:[12/15], Loss_G = 3.901349, Loss_D = 0.012511.
#
# Epoch:[1039/1500], Iteration:[14/15], Loss_G = 4.055479, Loss_D = 0.012782.
#
# Epoch:[1039/1500], Loss_G = 4.055479, Loss_D = 0.012782.
#
# Epoch:[1040/1500], Iteration:[0/15], Loss_G = 3.838057, Loss_D = 0.011780.
#
# Epoch:[1040/1500], Iteration:[2/15], Loss_G = 4.018701, Loss_D = 0.016699.
#
# Epoch:[1040/1500], Iteration:[4/15], Loss_G = 3.982245, Loss_D = 0.019243.
#
# Epoch:[1040/1500], Iteration:[6/15], Loss_G = 3.883327, Loss_D = 0.013575.
#
# Epoch:[1040/1500], Iteration:[8/15], Loss_G = 3.831377, Loss_D = 0.011840.
#
# Epoch:[1040/1500], Iteration:[10/15], Loss_G = 3.923750, Loss_D = 0.011754.
#
# Epoch:[1040/1500], Iteration:[12/15], Loss_G = 3.852826, Loss_D = 0.011468.
#
# Epoch:[1040/1500], Iteration:[14/15], Loss_G = 3.917399, Loss_D = 0.011440.
#
# Epoch:[1040/1500], Loss_G = 3.917399, Loss_D = 0.011440.
#
# Epoch:[1041/1500], Iteration:[0/15], Loss_G = 3.993316, Loss_D = 0.012636.
#
# Epoch:[1041/1500], Iteration:[2/15], Loss_G = 3.939108, Loss_D = 0.013264.
#
# Epoch:[1041/1500], Iteration:[4/15], Loss_G = 3.807563, Loss_D = 0.012841.
#
# Epoch:[1041/1500], Iteration:[6/15], Loss_G = 3.958598, Loss_D = 0.012587.
#
# Epoch:[1041/1500], Iteration:[8/15], Loss_G = 3.915078, Loss_D = 0.014512.
#
# Epoch:[1041/1500], Iteration:[10/15], Loss_G = 4.062057, Loss_D = 0.013007.
#
# Epoch:[1041/1500], Iteration:[12/15], Loss_G = 3.991953, Loss_D = 0.011613.
#
# Epoch:[1041/1500], Iteration:[14/15], Loss_G = 4.058322, Loss_D = 0.013869.
#
# Epoch:[1041/1500], Loss_G = 4.058322, Loss_D = 0.013869.
#
# Epoch:[1042/1500], Iteration:[0/15], Loss_G = 3.927830, Loss_D = 0.012682.
#
# Epoch:[1042/1500], Iteration:[2/15], Loss_G = 3.913792, Loss_D = 0.012410.
#
# Epoch:[1042/1500], Iteration:[4/15], Loss_G = 3.961820, Loss_D = 0.011880.
#
# Epoch:[1042/1500], Iteration:[6/15], Loss_G = 3.791833, Loss_D = 0.013190.
#
# Epoch:[1042/1500], Iteration:[8/15], Loss_G = 3.983923, Loss_D = 0.013245.
#
# Epoch:[1042/1500], Iteration:[10/15], Loss_G = 3.988712, Loss_D = 0.011026.
#
# Epoch:[1042/1500], Iteration:[12/15], Loss_G = 4.021546, Loss_D = 0.012695.
#
# Epoch:[1042/1500], Iteration:[14/15], Loss_G = 4.001670, Loss_D = 0.016103.
#
# Epoch:[1042/1500], Loss_G = 4.001670, Loss_D = 0.016103.
#
# Epoch:[1043/1500], Iteration:[0/15], Loss_G = 4.005501, Loss_D = 0.011279.
#
# Epoch:[1043/1500], Iteration:[2/15], Loss_G = 3.999466, Loss_D = 0.010965.
#
# Epoch:[1043/1500], Iteration:[4/15], Loss_G = 3.887730, Loss_D = 0.012258.
#
# Epoch:[1043/1500], Iteration:[6/15], Loss_G = 3.897121, Loss_D = 0.013862.
#
# Epoch:[1043/1500], Iteration:[8/15], Loss_G = 3.997022, Loss_D = 0.011958.
#
# Epoch:[1043/1500], Iteration:[10/15], Loss_G = 4.002263, Loss_D = 0.011829.
#
# Epoch:[1043/1500], Iteration:[12/15], Loss_G = 4.037299, Loss_D = 0.013065.
#
# Epoch:[1043/1500], Iteration:[14/15], Loss_G = 3.831950, Loss_D = 0.013617.
#
# Epoch:[1043/1500], Loss_G = 3.831950, Loss_D = 0.013617.
#
# Epoch:[1044/1500], Iteration:[0/15], Loss_G = 3.879966, Loss_D = 0.011924.
#
# Epoch:[1044/1500], Iteration:[2/15], Loss_G = 3.958771, Loss_D = 0.012316.
#
# Epoch:[1044/1500], Iteration:[4/15], Loss_G = 3.922204, Loss_D = 0.011887.
#
# Epoch:[1044/1500], Iteration:[6/15], Loss_G = 3.929440, Loss_D = 0.012867.
#
# Epoch:[1044/1500], Iteration:[8/15], Loss_G = 4.013329, Loss_D = 0.014038.
#
# Epoch:[1044/1500], Iteration:[10/15], Loss_G = 3.769980, Loss_D = 0.012313.
#
# Epoch:[1044/1500], Iteration:[12/15], Loss_G = 4.006909, Loss_D = 0.012648.
#
# Epoch:[1044/1500], Iteration:[14/15], Loss_G = 3.975987, Loss_D = 0.012280.
#
# Epoch:[1044/1500], Loss_G = 3.975987, Loss_D = 0.012280.
#
# Epoch:[1045/1500], Iteration:[0/15], Loss_G = 3.955071, Loss_D = 0.016178.
#
# Epoch:[1045/1500], Iteration:[2/15], Loss_G = 3.993617, Loss_D = 0.018413.
#
# Epoch:[1045/1500], Iteration:[4/15], Loss_G = 3.886022, Loss_D = 0.011110.
#
# Epoch:[1045/1500], Iteration:[6/15], Loss_G = 3.933923, Loss_D = 0.012901.
#
# Epoch:[1045/1500], Iteration:[8/15], Loss_G = 4.058260, Loss_D = 0.012063.
#
# Epoch:[1045/1500], Iteration:[10/15], Loss_G = 4.009794, Loss_D = 0.013783.
#
# Epoch:[1045/1500], Iteration:[12/15], Loss_G = 3.867316, Loss_D = 0.011956.
#
# Epoch:[1045/1500], Iteration:[14/15], Loss_G = 3.901580, Loss_D = 0.012885.
#
# Epoch:[1045/1500], Loss_G = 3.901580, Loss_D = 0.012885.
#
# Epoch:[1046/1500], Iteration:[0/15], Loss_G = 4.066248, Loss_D = 0.011757.
#
# Epoch:[1046/1500], Iteration:[2/15], Loss_G = 3.824323, Loss_D = 0.012386.
#
# Epoch:[1046/1500], Iteration:[4/15], Loss_G = 3.894279, Loss_D = 0.012091.
#
# Epoch:[1046/1500], Iteration:[6/15], Loss_G = 3.995531, Loss_D = 0.012899.
#
# Epoch:[1046/1500], Iteration:[8/15], Loss_G = 3.922122, Loss_D = 0.015523.
#
# Epoch:[1046/1500], Iteration:[10/15], Loss_G = 3.937935, Loss_D = 0.011594.
#
# Epoch:[1046/1500], Iteration:[12/15], Loss_G = 4.080668, Loss_D = 0.013704.
#
# Epoch:[1046/1500], Iteration:[14/15], Loss_G = 4.038383, Loss_D = 0.012612.
#
# Epoch:[1046/1500], Loss_G = 4.038383, Loss_D = 0.012612.
#
# Epoch:[1047/1500], Iteration:[0/15], Loss_G = 4.032828, Loss_D = 0.012373.
#
# Epoch:[1047/1500], Iteration:[2/15], Loss_G = 3.955734, Loss_D = 0.013731.
#
# Epoch:[1047/1500], Iteration:[4/15], Loss_G = 3.941060, Loss_D = 0.014501.
#
# Epoch:[1047/1500], Iteration:[6/15], Loss_G = 3.948478, Loss_D = 0.011077.
#
# Epoch:[1047/1500], Iteration:[8/15], Loss_G = 4.090408, Loss_D = 0.015997.
#
# Epoch:[1047/1500], Iteration:[10/15], Loss_G = 3.980398, Loss_D = 0.011278.
#
# Epoch:[1047/1500], Iteration:[12/15], Loss_G = 3.920110, Loss_D = 0.014311.
#
# Epoch:[1047/1500], Iteration:[14/15], Loss_G = 4.106940, Loss_D = 0.011890.
#
# Epoch:[1047/1500], Loss_G = 4.106940, Loss_D = 0.011890.
#
# Epoch:[1048/1500], Iteration:[0/15], Loss_G = 3.972702, Loss_D = 0.011619.
#
# Epoch:[1048/1500], Iteration:[2/15], Loss_G = 3.938514, Loss_D = 0.011760.
#
# Epoch:[1048/1500], Iteration:[4/15], Loss_G = 3.960317, Loss_D = 0.014019.
#
# Epoch:[1048/1500], Iteration:[6/15], Loss_G = 3.925408, Loss_D = 0.012829.
#
# Epoch:[1048/1500], Iteration:[8/15], Loss_G = 3.879876, Loss_D = 0.014258.
#
# Epoch:[1048/1500], Iteration:[10/15], Loss_G = 3.938620, Loss_D = 0.014697.
#
# Epoch:[1048/1500], Iteration:[12/15], Loss_G = 3.879925, Loss_D = 0.012862.
#
# Epoch:[1048/1500], Iteration:[14/15], Loss_G = 3.859600, Loss_D = 0.011963.
#
# Epoch:[1048/1500], Loss_G = 3.859600, Loss_D = 0.011963.
#
# Epoch:[1049/1500], Iteration:[0/15], Loss_G = 3.965686, Loss_D = 0.011187.
#
# Epoch:[1049/1500], Iteration:[2/15], Loss_G = 4.076008, Loss_D = 0.015424.
#
# Epoch:[1049/1500], Iteration:[4/15], Loss_G = 3.846740, Loss_D = 0.012420.
#
# Epoch:[1049/1500], Iteration:[6/15], Loss_G = 3.956242, Loss_D = 0.015400.
#
# Epoch:[1049/1500], Iteration:[8/15], Loss_G = 3.960546, Loss_D = 0.012211.
#
# Epoch:[1049/1500], Iteration:[10/15], Loss_G = 4.017040, Loss_D = 0.012870.
#
# Epoch:[1049/1500], Iteration:[12/15], Loss_G = 3.927720, Loss_D = 0.011778.
#
# Epoch:[1049/1500], Iteration:[14/15], Loss_G = 3.916433, Loss_D = 0.011329.
#
# Epoch:[1049/1500], Loss_G = 3.916433, Loss_D = 0.011329.
#
# Epoch:[1050/1500], Iteration:[0/15], Loss_G = 3.939586, Loss_D = 0.013658.
#
# Epoch:[1050/1500], Iteration:[2/15], Loss_G = 3.929437, Loss_D = 0.012729.
#
# Epoch:[1050/1500], Iteration:[4/15], Loss_G = 4.007738, Loss_D = 0.012382.
#
# Epoch:[1050/1500], Iteration:[6/15], Loss_G = 3.970776, Loss_D = 0.013962.
#
# Epoch:[1050/1500], Iteration:[8/15], Loss_G = 4.014785, Loss_D = 0.012428.
#
# Epoch:[1050/1500], Iteration:[10/15], Loss_G = 3.933297, Loss_D = 0.012514.
#
# Epoch:[1050/1500], Iteration:[12/15], Loss_G = 3.870434, Loss_D = 0.012105.
#
# Epoch:[1050/1500], Iteration:[14/15], Loss_G = 3.824641, Loss_D = 0.011503.
#
# Epoch:[1050/1500], Loss_G = 3.824641, Loss_D = 0.011503.
#
# Epoch:[1051/1500], Iteration:[0/15], Loss_G = 4.086874, Loss_D = 0.011870.
#
# Epoch:[1051/1500], Iteration:[2/15], Loss_G = 3.949223, Loss_D = 0.012605.
#
# Epoch:[1051/1500], Iteration:[4/15], Loss_G = 3.965722, Loss_D = 0.012857.
#
# Epoch:[1051/1500], Iteration:[6/15], Loss_G = 3.946315, Loss_D = 0.012219.
#
# Epoch:[1051/1500], Iteration:[8/15], Loss_G = 3.968007, Loss_D = 0.011518.
#
# Epoch:[1051/1500], Iteration:[10/15], Loss_G = 3.943408, Loss_D = 0.012649.
#
# Epoch:[1051/1500], Iteration:[12/15], Loss_G = 3.955231, Loss_D = 0.013182.
#
# Epoch:[1051/1500], Iteration:[14/15], Loss_G = 3.926733, Loss_D = 0.013575.
#
# Epoch:[1051/1500], Loss_G = 3.926733, Loss_D = 0.013575.
#
# Epoch:[1052/1500], Iteration:[0/15], Loss_G = 3.957031, Loss_D = 0.013250.
#
# Epoch:[1052/1500], Iteration:[2/15], Loss_G = 3.992822, Loss_D = 0.011659.
#
# Epoch:[1052/1500], Iteration:[4/15], Loss_G = 3.959144, Loss_D = 0.015158.
#
# Epoch:[1052/1500], Iteration:[6/15], Loss_G = 3.733425, Loss_D = 0.011802.
#
# Epoch:[1052/1500], Iteration:[8/15], Loss_G = 3.940827, Loss_D = 0.012985.
#
# Epoch:[1052/1500], Iteration:[10/15], Loss_G = 3.918528, Loss_D = 0.015174.
#
# Epoch:[1052/1500], Iteration:[12/15], Loss_G = 4.001490, Loss_D = 0.011678.
#
# Epoch:[1052/1500], Iteration:[14/15], Loss_G = 3.882435, Loss_D = 0.010815.
#
# Epoch:[1052/1500], Loss_G = 3.882435, Loss_D = 0.010815.
#
# Epoch:[1053/1500], Iteration:[0/15], Loss_G = 3.909434, Loss_D = 0.013698.
#
# Epoch:[1053/1500], Iteration:[2/15], Loss_G = 3.924874, Loss_D = 0.015004.
#
# Epoch:[1053/1500], Iteration:[4/15], Loss_G = 3.882917, Loss_D = 0.011114.
#
# Epoch:[1053/1500], Iteration:[6/15], Loss_G = 3.937692, Loss_D = 0.013256.
#
# Epoch:[1053/1500], Iteration:[8/15], Loss_G = 3.826508, Loss_D = 0.012569.
#
# Epoch:[1053/1500], Iteration:[10/15], Loss_G = 3.961275, Loss_D = 0.011821.
#
# Epoch:[1053/1500], Iteration:[12/15], Loss_G = 3.855360, Loss_D = 0.013681.
#
# Epoch:[1053/1500], Iteration:[14/15], Loss_G = 4.050025, Loss_D = 0.019026.
#
# Epoch:[1053/1500], Loss_G = 4.050025, Loss_D = 0.019026.
#
# Epoch:[1054/1500], Iteration:[0/15], Loss_G = 3.914485, Loss_D = 0.010666.
#
# Epoch:[1054/1500], Iteration:[2/15], Loss_G = 3.918434, Loss_D = 0.016729.
#
# Epoch:[1054/1500], Iteration:[4/15], Loss_G = 3.791936, Loss_D = 0.011500.
#
# Epoch:[1054/1500], Iteration:[6/15], Loss_G = 3.926503, Loss_D = 0.013084.
#
# Epoch:[1054/1500], Iteration:[8/15], Loss_G = 3.971031, Loss_D = 0.012388.
#
# Epoch:[1054/1500], Iteration:[10/15], Loss_G = 3.888210, Loss_D = 0.014004.
#
# Epoch:[1054/1500], Iteration:[12/15], Loss_G = 4.085790, Loss_D = 0.014285.
#
# Epoch:[1054/1500], Iteration:[14/15], Loss_G = 3.946002, Loss_D = 0.010634.
#
# Epoch:[1054/1500], Loss_G = 3.946002, Loss_D = 0.010634.
#
# Epoch:[1055/1500], Iteration:[0/15], Loss_G = 3.949563, Loss_D = 0.014225.
#
# Epoch:[1055/1500], Iteration:[2/15], Loss_G = 3.974136, Loss_D = 0.015790.
#
# Epoch:[1055/1500], Iteration:[4/15], Loss_G = 3.859233, Loss_D = 0.011238.
#
# Epoch:[1055/1500], Iteration:[6/15], Loss_G = 3.909909, Loss_D = 0.012979.
#
# Epoch:[1055/1500], Iteration:[8/15], Loss_G = 3.939562, Loss_D = 0.010939.
#
# Epoch:[1055/1500], Iteration:[10/15], Loss_G = 3.872171, Loss_D = 0.013456.
#
# Epoch:[1055/1500], Iteration:[12/15], Loss_G = 3.996542, Loss_D = 0.011564.
#
# Epoch:[1055/1500], Iteration:[14/15], Loss_G = 4.035376, Loss_D = 0.011356.
#
# Epoch:[1055/1500], Loss_G = 4.035376, Loss_D = 0.011356.
#
# Epoch:[1056/1500], Iteration:[0/15], Loss_G = 3.968517, Loss_D = 0.011275.
#
# Epoch:[1056/1500], Iteration:[2/15], Loss_G = 3.886376, Loss_D = 0.013513.
#
# Epoch:[1056/1500], Iteration:[4/15], Loss_G = 3.808006, Loss_D = 0.011411.
#
# Epoch:[1056/1500], Iteration:[6/15], Loss_G = 3.937907, Loss_D = 0.012961.
#
# Epoch:[1056/1500], Iteration:[8/15], Loss_G = 3.832194, Loss_D = 0.014380.
#
# Epoch:[1056/1500], Iteration:[10/15], Loss_G = 3.884393, Loss_D = 0.011204.
#
# Epoch:[1056/1500], Iteration:[12/15], Loss_G = 4.032549, Loss_D = 0.012428.
#
# Epoch:[1056/1500], Iteration:[14/15], Loss_G = 4.006305, Loss_D = 0.012169.
#
# Epoch:[1056/1500], Loss_G = 4.006305, Loss_D = 0.012169.
#
# Epoch:[1057/1500], Iteration:[0/15], Loss_G = 3.906346, Loss_D = 0.011074.
#
# Epoch:[1057/1500], Iteration:[2/15], Loss_G = 3.868090, Loss_D = 0.012707.
#
# Epoch:[1057/1500], Iteration:[4/15], Loss_G = 3.887715, Loss_D = 0.011856.
#
# Epoch:[1057/1500], Iteration:[6/15], Loss_G = 3.900527, Loss_D = 0.011889.
#
# Epoch:[1057/1500], Iteration:[8/15], Loss_G = 3.949228, Loss_D = 0.012267.
#
# Epoch:[1057/1500], Iteration:[10/15], Loss_G = 3.871593, Loss_D = 0.012018.
#
# Epoch:[1057/1500], Iteration:[12/15], Loss_G = 4.020062, Loss_D = 0.011844.
#
# Epoch:[1057/1500], Iteration:[14/15], Loss_G = 3.998224, Loss_D = 0.013433.
#
# Epoch:[1057/1500], Loss_G = 3.998224, Loss_D = 0.013433.
#
# Epoch:[1058/1500], Iteration:[0/15], Loss_G = 3.937858, Loss_D = 0.015183.
#
# Epoch:[1058/1500], Iteration:[2/15], Loss_G = 4.041358, Loss_D = 0.011607.
#
# Epoch:[1058/1500], Iteration:[4/15], Loss_G = 4.015430, Loss_D = 0.014593.
#
# Epoch:[1058/1500], Iteration:[6/15], Loss_G = 3.980739, Loss_D = 0.011920.
#
# Epoch:[1058/1500], Iteration:[8/15], Loss_G = 4.023375, Loss_D = 0.011776.
#
# Epoch:[1058/1500], Iteration:[10/15], Loss_G = 4.002012, Loss_D = 0.013123.
#
# Epoch:[1058/1500], Iteration:[12/15], Loss_G = 3.993518, Loss_D = 0.011420.
#
# Epoch:[1058/1500], Iteration:[14/15], Loss_G = 3.934874, Loss_D = 0.014281.
#
# Epoch:[1058/1500], Loss_G = 3.934874, Loss_D = 0.014281.
#
# Epoch:[1059/1500], Iteration:[0/15], Loss_G = 4.014638, Loss_D = 0.011042.
#
# Epoch:[1059/1500], Iteration:[2/15], Loss_G = 3.949439, Loss_D = 0.010922.
#
# Epoch:[1059/1500], Iteration:[4/15], Loss_G = 3.827096, Loss_D = 0.014661.
#
# Epoch:[1059/1500], Iteration:[6/15], Loss_G = 3.994323, Loss_D = 0.012653.
#
# Epoch:[1059/1500], Iteration:[8/15], Loss_G = 4.040304, Loss_D = 0.011330.
#
# Epoch:[1059/1500], Iteration:[10/15], Loss_G = 3.936821, Loss_D = 0.012302.
#
# Epoch:[1059/1500], Iteration:[12/15], Loss_G = 4.027538, Loss_D = 0.013774.
#
# Epoch:[1059/1500], Iteration:[14/15], Loss_G = 3.882156, Loss_D = 0.011226.
#
# Epoch:[1059/1500], Loss_G = 3.882156, Loss_D = 0.011226.
#
# Epoch:[1060/1500], Iteration:[0/15], Loss_G = 3.844067, Loss_D = 0.012063.
#
# Epoch:[1060/1500], Iteration:[2/15], Loss_G = 4.083081, Loss_D = 0.013540.
#
# Epoch:[1060/1500], Iteration:[4/15], Loss_G = 3.991434, Loss_D = 0.012496.
#
# Epoch:[1060/1500], Iteration:[6/15], Loss_G = 3.966571, Loss_D = 0.010544.
#
# Epoch:[1060/1500], Iteration:[8/15], Loss_G = 4.001306, Loss_D = 0.011183.
#
# Epoch:[1060/1500], Iteration:[10/15], Loss_G = 4.009248, Loss_D = 0.014345.
#
# Epoch:[1060/1500], Iteration:[12/15], Loss_G = 3.925232, Loss_D = 0.013106.
#
# Epoch:[1060/1500], Iteration:[14/15], Loss_G = 3.908565, Loss_D = 0.014116.
#
# Epoch:[1060/1500], Loss_G = 3.908565, Loss_D = 0.014116.
#
# Epoch:[1061/1500], Iteration:[0/15], Loss_G = 3.870567, Loss_D = 0.012962.
#
# Epoch:[1061/1500], Iteration:[2/15], Loss_G = 3.913227, Loss_D = 0.014205.
#
# Epoch:[1061/1500], Iteration:[4/15], Loss_G = 4.052391, Loss_D = 0.011204.
#
# Epoch:[1061/1500], Iteration:[6/15], Loss_G = 3.914007, Loss_D = 0.012440.
#
# Epoch:[1061/1500], Iteration:[8/15], Loss_G = 4.007271, Loss_D = 0.013011.
#
# Epoch:[1061/1500], Iteration:[10/15], Loss_G = 3.870417, Loss_D = 0.011763.
#
# Epoch:[1061/1500], Iteration:[12/15], Loss_G = 3.936986, Loss_D = 0.013521.
#
# Epoch:[1061/1500], Iteration:[14/15], Loss_G = 3.966095, Loss_D = 0.011163.
#
# Epoch:[1061/1500], Loss_G = 3.966095, Loss_D = 0.011163.
#
# Epoch:[1062/1500], Iteration:[0/15], Loss_G = 4.013563, Loss_D = 0.011754.
#
# Epoch:[1062/1500], Iteration:[2/15], Loss_G = 3.981699, Loss_D = 0.014355.
#
# Epoch:[1062/1500], Iteration:[4/15], Loss_G = 3.977345, Loss_D = 0.015239.
#
# Epoch:[1062/1500], Iteration:[6/15], Loss_G = 4.054353, Loss_D = 0.011276.
#
# Epoch:[1062/1500], Iteration:[8/15], Loss_G = 3.923306, Loss_D = 0.011109.
#
# Epoch:[1062/1500], Iteration:[10/15], Loss_G = 3.926711, Loss_D = 0.011595.
#
# Epoch:[1062/1500], Iteration:[12/15], Loss_G = 3.835405, Loss_D = 0.011518.
#
# Epoch:[1062/1500], Iteration:[14/15], Loss_G = 3.915407, Loss_D = 0.013871.
#
# Epoch:[1062/1500], Loss_G = 3.915407, Loss_D = 0.013871.
#
# Epoch:[1063/1500], Iteration:[0/15], Loss_G = 3.918399, Loss_D = 0.017515.
#
# Epoch:[1063/1500], Iteration:[2/15], Loss_G = 3.892079, Loss_D = 0.011537.
#
# Epoch:[1063/1500], Iteration:[4/15], Loss_G = 3.934198, Loss_D = 0.013394.
#
# Epoch:[1063/1500], Iteration:[6/15], Loss_G = 3.979983, Loss_D = 0.014325.
#
# Epoch:[1063/1500], Iteration:[8/15], Loss_G = 3.881685, Loss_D = 0.013602.
#
# Epoch:[1063/1500], Iteration:[10/15], Loss_G = 3.984532, Loss_D = 0.012217.
#
# Epoch:[1063/1500], Iteration:[12/15], Loss_G = 3.887723, Loss_D = 0.013206.
#
# Epoch:[1063/1500], Iteration:[14/15], Loss_G = 3.789604, Loss_D = 0.012388.
#
# Epoch:[1063/1500], Loss_G = 3.789604, Loss_D = 0.012388.
#
# Epoch:[1064/1500], Iteration:[0/15], Loss_G = 3.921644, Loss_D = 0.012215.
#
# Epoch:[1064/1500], Iteration:[2/15], Loss_G = 3.942110, Loss_D = 0.011731.
#
# Epoch:[1064/1500], Iteration:[4/15], Loss_G = 4.023723, Loss_D = 0.012228.
#
# Epoch:[1064/1500], Iteration:[6/15], Loss_G = 3.929334, Loss_D = 0.014531.
#
# Epoch:[1064/1500], Iteration:[8/15], Loss_G = 3.994900, Loss_D = 0.012326.
#
# Epoch:[1064/1500], Iteration:[10/15], Loss_G = 3.954065, Loss_D = 0.012966.
#
# Epoch:[1064/1500], Iteration:[12/15], Loss_G = 3.941650, Loss_D = 0.010873.
#
# Epoch:[1064/1500], Iteration:[14/15], Loss_G = 3.961180, Loss_D = 0.013076.
#
# Epoch:[1064/1500], Loss_G = 3.961180, Loss_D = 0.013076.
#
# Epoch:[1065/1500], Iteration:[0/15], Loss_G = 3.961030, Loss_D = 0.012079.
#
# Epoch:[1065/1500], Iteration:[2/15], Loss_G = 4.090407, Loss_D = 0.011970.
#
# Epoch:[1065/1500], Iteration:[4/15], Loss_G = 3.963051, Loss_D = 0.014901.
#
# Epoch:[1065/1500], Iteration:[6/15], Loss_G = 3.936683, Loss_D = 0.011807.
#
# Epoch:[1065/1500], Iteration:[8/15], Loss_G = 3.944398, Loss_D = 0.012180.
#
# Epoch:[1065/1500], Iteration:[10/15], Loss_G = 3.993906, Loss_D = 0.011851.
#
# Epoch:[1065/1500], Iteration:[12/15], Loss_G = 3.928624, Loss_D = 0.013698.
#
# Epoch:[1065/1500], Iteration:[14/15], Loss_G = 3.968213, Loss_D = 0.014460.
#
# Epoch:[1065/1500], Loss_G = 3.968213, Loss_D = 0.014460.
#
# Epoch:[1066/1500], Iteration:[0/15], Loss_G = 3.994107, Loss_D = 0.012856.
#
# Epoch:[1066/1500], Iteration:[2/15], Loss_G = 3.958990, Loss_D = 0.011523.
#
# Epoch:[1066/1500], Iteration:[4/15], Loss_G = 3.925565, Loss_D = 0.012025.
#
# Epoch:[1066/1500], Iteration:[6/15], Loss_G = 3.898573, Loss_D = 0.012797.
#
# Epoch:[1066/1500], Iteration:[8/15], Loss_G = 3.939795, Loss_D = 0.011671.
#
# Epoch:[1066/1500], Iteration:[10/15], Loss_G = 3.986685, Loss_D = 0.011719.
#
# Epoch:[1066/1500], Iteration:[12/15], Loss_G = 3.989726, Loss_D = 0.014159.
#
# Epoch:[1066/1500], Iteration:[14/15], Loss_G = 3.950022, Loss_D = 0.016289.
#
# Epoch:[1066/1500], Loss_G = 3.950022, Loss_D = 0.016289.
#
# Epoch:[1067/1500], Iteration:[0/15], Loss_G = 3.894387, Loss_D = 0.012173.
#
# Epoch:[1067/1500], Iteration:[2/15], Loss_G = 3.916077, Loss_D = 0.016158.
#
# Epoch:[1067/1500], Iteration:[4/15], Loss_G = 3.987575, Loss_D = 0.011959.
#
# Epoch:[1067/1500], Iteration:[6/15], Loss_G = 3.817631, Loss_D = 0.012157.
#
# Epoch:[1067/1500], Iteration:[8/15], Loss_G = 3.971624, Loss_D = 0.011237.
#
# Epoch:[1067/1500], Iteration:[10/15], Loss_G = 3.923860, Loss_D = 0.011558.
#
# Epoch:[1067/1500], Iteration:[12/15], Loss_G = 3.905548, Loss_D = 0.013703.
#
# Epoch:[1067/1500], Iteration:[14/15], Loss_G = 3.993203, Loss_D = 0.012903.
#
# Epoch:[1067/1500], Loss_G = 3.993203, Loss_D = 0.012903.
#
# Epoch:[1068/1500], Iteration:[0/15], Loss_G = 3.937703, Loss_D = 0.011500.
#
# Epoch:[1068/1500], Iteration:[2/15], Loss_G = 3.920477, Loss_D = 0.012144.
#
# Epoch:[1068/1500], Iteration:[4/15], Loss_G = 4.022034, Loss_D = 0.012124.
#
# Epoch:[1068/1500], Iteration:[6/15], Loss_G = 3.956866, Loss_D = 0.013767.
#
# Epoch:[1068/1500], Iteration:[8/15], Loss_G = 3.938187, Loss_D = 0.013053.
#
# Epoch:[1068/1500], Iteration:[10/15], Loss_G = 3.974550, Loss_D = 0.011204.
#
# Epoch:[1068/1500], Iteration:[12/15], Loss_G = 3.929057, Loss_D = 0.012421.
#
# Epoch:[1068/1500], Iteration:[14/15], Loss_G = 4.056015, Loss_D = 0.011737.
#
# Epoch:[1068/1500], Loss_G = 4.056015, Loss_D = 0.011737.
#
# Epoch:[1069/1500], Iteration:[0/15], Loss_G = 4.007231, Loss_D = 0.010597.
#
# Epoch:[1069/1500], Iteration:[2/15], Loss_G = 3.794747, Loss_D = 0.011266.
#
# Epoch:[1069/1500], Iteration:[4/15], Loss_G = 4.043012, Loss_D = 0.012035.
#
# Epoch:[1069/1500], Iteration:[6/15], Loss_G = 3.981673, Loss_D = 0.011992.
#
# Epoch:[1069/1500], Iteration:[8/15], Loss_G = 3.911633, Loss_D = 0.010377.
#
# Epoch:[1069/1500], Iteration:[10/15], Loss_G = 4.057896, Loss_D = 0.012357.
#
# Epoch:[1069/1500], Iteration:[12/15], Loss_G = 3.867715, Loss_D = 0.012220.
#
# Epoch:[1069/1500], Iteration:[14/15], Loss_G = 3.942013, Loss_D = 0.012747.
#
# Epoch:[1069/1500], Loss_G = 3.942013, Loss_D = 0.012747.
#
# Epoch:[1070/1500], Iteration:[0/15], Loss_G = 3.926680, Loss_D = 0.012117.
#
# Epoch:[1070/1500], Iteration:[2/15], Loss_G = 3.980239, Loss_D = 0.010269.
#
# Epoch:[1070/1500], Iteration:[4/15], Loss_G = 4.019310, Loss_D = 0.010847.
#
# Epoch:[1070/1500], Iteration:[6/15], Loss_G = 4.040498, Loss_D = 0.012222.
#
# Epoch:[1070/1500], Iteration:[8/15], Loss_G = 3.867229, Loss_D = 0.012380.
#
# Epoch:[1070/1500], Iteration:[10/15], Loss_G = 3.915452, Loss_D = 0.011435.
#
# Epoch:[1070/1500], Iteration:[12/15], Loss_G = 3.826706, Loss_D = 0.011389.
#
# Epoch:[1070/1500], Iteration:[14/15], Loss_G = 3.944004, Loss_D = 0.014177.
#
# Epoch:[1070/1500], Loss_G = 3.944004, Loss_D = 0.014177.
#
# Epoch:[1071/1500], Iteration:[0/15], Loss_G = 3.900349, Loss_D = 0.012279.
#
# Epoch:[1071/1500], Iteration:[2/15], Loss_G = 3.927885, Loss_D = 0.010606.
#
# Epoch:[1071/1500], Iteration:[4/15], Loss_G = 3.998781, Loss_D = 0.012556.
#
# Epoch:[1071/1500], Iteration:[6/15], Loss_G = 4.021223, Loss_D = 0.015744.
#
# Epoch:[1071/1500], Iteration:[8/15], Loss_G = 3.978742, Loss_D = 0.014824.
#
# Epoch:[1071/1500], Iteration:[10/15], Loss_G = 3.951967, Loss_D = 0.013004.
#
# Epoch:[1071/1500], Iteration:[12/15], Loss_G = 4.047349, Loss_D = 0.011941.
#
# Epoch:[1071/1500], Iteration:[14/15], Loss_G = 3.926929, Loss_D = 0.016323.
#
# Epoch:[1071/1500], Loss_G = 3.926929, Loss_D = 0.016323.
#
# Epoch:[1072/1500], Iteration:[0/15], Loss_G = 3.982810, Loss_D = 0.024848.
#
# Epoch:[1072/1500], Iteration:[2/15], Loss_G = 3.922927, Loss_D = 0.012390.
#
# Epoch:[1072/1500], Iteration:[4/15], Loss_G = 3.967253, Loss_D = 0.011901.
#
# Epoch:[1072/1500], Iteration:[6/15], Loss_G = 4.007824, Loss_D = 0.012891.
#
# Epoch:[1072/1500], Iteration:[8/15], Loss_G = 3.816535, Loss_D = 0.010753.
#
# Epoch:[1072/1500], Iteration:[10/15], Loss_G = 3.926285, Loss_D = 0.011806.
#
# ...
#
# Epoch:[1477/1500], Iteration:[2/15], Loss_G = 3.932416, Loss_D = 0.011138.
#
# Epoch:[1477/1500], Iteration:[4/15], Loss_G = 3.920379, Loss_D = 0.010958.
#
# Epoch:[1477/1500], Iteration:[6/15], Loss_G = 3.924858, Loss_D = 0.012077.
#
# Epoch:[1477/1500], Iteration:[8/15], Loss_G = 4.022815, Loss_D = 0.013677.
#
# Epoch:[1477/1500], Iteration:[10/15], Loss_G = 4.017630, Loss_D = 0.013031.
#
# Epoch:[1477/1500], Iteration:[12/15], Loss_G = 3.839939, Loss_D = 0.012432.
#
# Epoch:[1477/1500], Iteration:[14/15], Loss_G = 3.948831, Loss_D = 0.014527.
#
# Epoch:[1477/1500], Loss_G = 3.948831, Loss_D = 0.014527.
#
# Epoch:[1478/1500], Iteration:[0/15], Loss_G = 3.947201, Loss_D = 0.011388.
#
# Epoch:[1478/1500], Iteration:[2/15], Loss_G = 4.032516, Loss_D = 0.012753.
#
# Epoch:[1478/1500], Iteration:[4/15], Loss_G = 3.842704, Loss_D = 0.013206.
#
# Epoch:[1478/1500], Iteration:[6/15], Loss_G = 3.806402, Loss_D = 0.012688.
#
# Epoch:[1478/1500], Iteration:[8/15], Loss_G = 4.094342, Loss_D = 0.011854.
#
# Epoch:[1478/1500], Iteration:[10/15], Loss_G = 3.932930, Loss_D = 0.011642.
#
# Epoch:[1478/1500], Iteration:[12/15], Loss_G = 4.030883, Loss_D = 0.011258.
#
# Epoch:[1478/1500], Iteration:[14/15], Loss_G = 3.854099, Loss_D = 0.013493.
#
# Epoch:[1478/1500], Loss_G = 3.854099, Loss_D = 0.013493.
#
# Epoch:[1479/1500], Iteration:[0/15], Loss_G = 3.929667, Loss_D = 0.016105.
#
# Epoch:[1479/1500], Iteration:[2/15], Loss_G = 3.895964, Loss_D = 0.012374.
#
# Epoch:[1479/1500], Iteration:[4/15], Loss_G = 3.917856, Loss_D = 0.011380.
#
# Epoch:[1479/1500], Iteration:[6/15], Loss_G = 4.035498, Loss_D = 0.012595.
#
# Epoch:[1479/1500], Iteration:[8/15], Loss_G = 3.846855, Loss_D = 0.010144.
#
# Epoch:[1479/1500], Iteration:[10/15], Loss_G = 3.905515, Loss_D = 0.012475.
#
# Epoch:[1479/1500], Iteration:[12/15], Loss_G = 3.915892, Loss_D = 0.012283.
#
# Epoch:[1479/1500], Iteration:[14/15], Loss_G = 3.936637, Loss_D = 0.012555.
#
# Epoch:[1479/1500], Loss_G = 3.936637, Loss_D = 0.012555.
#
# Epoch:[1480/1500], Iteration:[0/15], Loss_G = 3.989858, Loss_D = 0.012540.
#
# Epoch:[1480/1500], Iteration:[2/15], Loss_G = 4.009629, Loss_D = 0.014771.
#
# Epoch:[1480/1500], Iteration:[4/15], Loss_G = 4.155656, Loss_D = 0.015993.
#
# Epoch:[1480/1500], Iteration:[6/15], Loss_G = 3.870184, Loss_D = 0.013005.
#
# Epoch:[1480/1500], Iteration:[8/15], Loss_G = 4.053915, Loss_D = 0.012603.
#
# Epoch:[1480/1500], Iteration:[10/15], Loss_G = 3.964648, Loss_D = 0.019107.
#
# Epoch:[1480/1500], Iteration:[12/15], Loss_G = 3.929306, Loss_D = 0.012219.
#
# Epoch:[1480/1500], Iteration:[14/15], Loss_G = 3.871876, Loss_D = 0.011099.
#
# Epoch:[1480/1500], Loss_G = 3.871876, Loss_D = 0.011099.
#
# Epoch:[1481/1500], Iteration:[0/15], Loss_G = 3.982270, Loss_D = 0.014342.
#
# Epoch:[1481/1500], Iteration:[2/15], Loss_G = 3.963865, Loss_D = 0.011604.
#
# Epoch:[1481/1500], Iteration:[4/15], Loss_G = 3.925152, Loss_D = 0.012129.
#
# Epoch:[1481/1500], Iteration:[6/15], Loss_G = 3.987783, Loss_D = 0.011874.
#
# Epoch:[1481/1500], Iteration:[8/15], Loss_G = 3.959902, Loss_D = 0.010914.
#
# Epoch:[1481/1500], Iteration:[10/15], Loss_G = 3.954260, Loss_D = 0.010969.
#
# Epoch:[1481/1500], Iteration:[12/15], Loss_G = 3.982366, Loss_D = 0.013557.
#
# Epoch:[1481/1500], Iteration:[14/15], Loss_G = 3.938871, Loss_D = 0.012802.
#
# Epoch:[1481/1500], Loss_G = 3.938871, Loss_D = 0.012802.
#
# Epoch:[1482/1500], Iteration:[0/15], Loss_G = 4.072370, Loss_D = 0.010893.
#
# Epoch:[1482/1500], Iteration:[2/15], Loss_G = 3.838230, Loss_D = 0.018945.
#
# Epoch:[1482/1500], Iteration:[4/15], Loss_G = 4.012695, Loss_D = 0.015689.
#
# Epoch:[1482/1500], Iteration:[6/15], Loss_G = 3.921138, Loss_D = 0.011898.
#
# Epoch:[1482/1500], Iteration:[8/15], Loss_G = 3.949137, Loss_D = 0.013719.
#
# Epoch:[1482/1500], Iteration:[10/15], Loss_G = 4.012344, Loss_D = 0.011031.
#
# Epoch:[1482/1500], Iteration:[12/15], Loss_G = 3.983032, Loss_D = 0.011377.
#
# Epoch:[1482/1500], Iteration:[14/15], Loss_G = 4.025058, Loss_D = 0.014154.
#
# Epoch:[1482/1500], Loss_G = 4.025058, Loss_D = 0.014154.
#
# Epoch:[1483/1500], Iteration:[0/15], Loss_G = 3.836678, Loss_D = 0.014223.
#
# Epoch:[1483/1500], Iteration:[2/15], Loss_G = 4.155606, Loss_D = 0.013860.
#
# Epoch:[1483/1500], Iteration:[4/15], Loss_G = 3.850248, Loss_D = 0.012454.
#
# Epoch:[1483/1500], Iteration:[6/15], Loss_G = 3.996711, Loss_D = 0.012550.
#
# Epoch:[1483/1500], Iteration:[8/15], Loss_G = 3.945034, Loss_D = 0.011461.
#
# Epoch:[1483/1500], Iteration:[10/15], Loss_G = 3.969964, Loss_D = 0.012566.
#
# Epoch:[1483/1500], Iteration:[12/15], Loss_G = 3.926539, Loss_D = 0.011796.
#
# Epoch:[1483/1500], Iteration:[14/15], Loss_G = 3.932211, Loss_D = 0.011718.
#
# Epoch:[1483/1500], Loss_G = 3.932211, Loss_D = 0.011718.
#
# Epoch:[1484/1500], Iteration:[0/15], Loss_G = 3.865686, Loss_D = 0.011551.
#
# Epoch:[1484/1500], Iteration:[2/15], Loss_G = 4.013531, Loss_D = 0.011643.
#
# Epoch:[1484/1500], Iteration:[4/15], Loss_G = 3.946793, Loss_D = 0.011910.
#
# Epoch:[1484/1500], Iteration:[6/15], Loss_G = 3.976781, Loss_D = 0.013466.
#
# Epoch:[1484/1500], Iteration:[8/15], Loss_G = 3.968064, Loss_D = 0.009996.
#
# Epoch:[1484/1500], Iteration:[10/15], Loss_G = 4.025473, Loss_D = 0.013140.
#
# Epoch:[1484/1500], Iteration:[12/15], Loss_G = 4.083558, Loss_D = 0.011601.
#
# Epoch:[1484/1500], Iteration:[14/15], Loss_G = 3.925236, Loss_D = 0.011627.
#
# Epoch:[1484/1500], Loss_G = 3.925236, Loss_D = 0.011627.
#
# Epoch:[1485/1500], Iteration:[0/15], Loss_G = 4.031969, Loss_D = 0.016145.
#
# Epoch:[1485/1500], Iteration:[2/15], Loss_G = 3.966045, Loss_D = 0.011437.
#
# Epoch:[1485/1500], Iteration:[4/15], Loss_G = 4.008402, Loss_D = 0.012792.
#
# Epoch:[1485/1500], Iteration:[6/15], Loss_G = 3.847027, Loss_D = 0.014651.
#
# Epoch:[1485/1500], Iteration:[8/15], Loss_G = 3.906501, Loss_D = 0.011928.
#
# Epoch:[1485/1500], Iteration:[10/15], Loss_G = 4.011157, Loss_D = 0.011993.
#
# Epoch:[1485/1500], Iteration:[12/15], Loss_G = 3.909449, Loss_D = 0.013768.
#
# Epoch:[1485/1500], Iteration:[14/15], Loss_G = 3.908733, Loss_D = 0.011131.
#
# Epoch:[1485/1500], Loss_G = 3.908733, Loss_D = 0.011131.
#
# Epoch:[1486/1500], Iteration:[0/15], Loss_G = 3.927695, Loss_D = 0.011635.
#
# Epoch:[1486/1500], Iteration:[2/15], Loss_G = 3.906265, Loss_D = 0.011386.
#
# Epoch:[1486/1500], Iteration:[4/15], Loss_G = 3.981488, Loss_D = 0.013245.
#
# Epoch:[1486/1500], Iteration:[6/15], Loss_G = 3.951098, Loss_D = 0.020535.
#
# Epoch:[1486/1500], Iteration:[8/15], Loss_G = 3.940943, Loss_D = 0.012382.
#
# Epoch:[1486/1500], Iteration:[10/15], Loss_G = 3.770778, Loss_D = 0.012357.
#
# Epoch:[1486/1500], Iteration:[12/15], Loss_G = 3.941914, Loss_D = 0.014831.
#
# Epoch:[1486/1500], Iteration:[14/15], Loss_G = 3.996147, Loss_D = 0.015022.
#
# Epoch:[1486/1500], Loss_G = 3.996147, Loss_D = 0.015022.
#
# Epoch:[1487/1500], Iteration:[0/15], Loss_G = 3.971869, Loss_D = 0.013150.
#
# Epoch:[1487/1500], Iteration:[2/15], Loss_G = 3.957715, Loss_D = 0.012130.
#
# Epoch:[1487/1500], Iteration:[4/15], Loss_G = 3.969187, Loss_D = 0.012776.
#
# Epoch:[1487/1500], Iteration:[6/15], Loss_G = 3.981807, Loss_D = 0.012395.
#
# Epoch:[1487/1500], Iteration:[8/15], Loss_G = 3.926992, Loss_D = 0.013773.
#
# Epoch:[1487/1500], Iteration:[10/15], Loss_G = 3.947852, Loss_D = 0.011531.
#
# Epoch:[1487/1500], Iteration:[12/15], Loss_G = 4.005106, Loss_D = 0.012063.
#
# Epoch:[1487/1500], Iteration:[14/15], Loss_G = 3.958629, Loss_D = 0.014411.
#
# Epoch:[1487/1500], Loss_G = 3.958629, Loss_D = 0.014411.
#
# Epoch:[1488/1500], Iteration:[0/15], Loss_G = 3.996343, Loss_D = 0.011469.
#
# Epoch:[1488/1500], Iteration:[2/15], Loss_G = 4.099670, Loss_D = 0.011865.
#
# Epoch:[1488/1500], Iteration:[4/15], Loss_G = 4.007463, Loss_D = 0.011682.
#
# Epoch:[1488/1500], Iteration:[6/15], Loss_G = 3.904517, Loss_D = 0.017587.
#
# Epoch:[1488/1500], Iteration:[8/15], Loss_G = 4.085997, Loss_D = 0.011437.
#
# Epoch:[1488/1500], Iteration:[10/15], Loss_G = 4.036961, Loss_D = 0.012652.
#
# Epoch:[1488/1500], Iteration:[12/15], Loss_G = 3.835567, Loss_D = 0.011769.
#
# Epoch:[1488/1500], Iteration:[14/15], Loss_G = 3.950121, Loss_D = 0.011591.
#
# Epoch:[1488/1500], Loss_G = 3.950121, Loss_D = 0.011591.
#
# Epoch:[1489/1500], Iteration:[0/15], Loss_G = 3.741864, Loss_D = 0.010683.
#
# Epoch:[1489/1500], Iteration:[2/15], Loss_G = 4.033622, Loss_D = 0.012349.
#
# Epoch:[1489/1500], Iteration:[4/15], Loss_G = 4.070012, Loss_D = 0.013688.
#
# Epoch:[1489/1500], Iteration:[6/15], Loss_G = 3.815075, Loss_D = 0.011756.
#
# Epoch:[1489/1500], Iteration:[8/15], Loss_G = 3.937791, Loss_D = 0.011096.
#
# Epoch:[1489/1500], Iteration:[10/15], Loss_G = 3.948784, Loss_D = 0.011922.
#
# Epoch:[1489/1500], Iteration:[12/15], Loss_G = 3.954210, Loss_D = 0.011670.
#
# Epoch:[1489/1500], Iteration:[14/15], Loss_G = 3.948501, Loss_D = 0.011140.
#
# Epoch:[1489/1500], Loss_G = 3.948501, Loss_D = 0.011140.
#
# Epoch:[1490/1500], Iteration:[0/15], Loss_G = 3.978667, Loss_D = 0.011955.
#
# Epoch:[1490/1500], Iteration:[2/15], Loss_G = 4.009028, Loss_D = 0.014348.
#
# Epoch:[1490/1500], Iteration:[4/15], Loss_G = 3.980365, Loss_D = 0.013757.
#
# Epoch:[1490/1500], Iteration:[6/15], Loss_G = 4.098854, Loss_D = 0.014061.
#
# Epoch:[1490/1500], Iteration:[8/15], Loss_G = 3.964708, Loss_D = 0.012952.
#
# Epoch:[1490/1500], Iteration:[10/15], Loss_G = 3.947229, Loss_D = 0.013048.
#
# Epoch:[1490/1500], Iteration:[12/15], Loss_G = 3.903262, Loss_D = 0.011655.
#
# Epoch:[1490/1500], Iteration:[14/15], Loss_G = 4.041907, Loss_D = 0.018314.
#
# Epoch:[1490/1500], Loss_G = 4.041907, Loss_D = 0.018314.
#
# Epoch:[1491/1500], Iteration:[0/15], Loss_G = 4.028945, Loss_D = 0.012642.
#
# Epoch:[1491/1500], Iteration:[2/15], Loss_G = 3.863884, Loss_D = 0.016742.
#
# Epoch:[1491/1500], Iteration:[4/15], Loss_G = 4.034454, Loss_D = 0.012721.
#
# Epoch:[1491/1500], Iteration:[6/15], Loss_G = 4.061691, Loss_D = 0.011130.
#
# Epoch:[1491/1500], Iteration:[8/15], Loss_G = 3.943969, Loss_D = 0.012517.
#
# Epoch:[1491/1500], Iteration:[10/15], Loss_G = 3.888110, Loss_D = 0.015944.
#
# Epoch:[1491/1500], Iteration:[12/15], Loss_G = 3.892754, Loss_D = 0.012651.
#
# Epoch:[1491/1500], Iteration:[14/15], Loss_G = 4.063018, Loss_D = 0.011197.
#
# Epoch:[1491/1500], Loss_G = 4.063018, Loss_D = 0.011197.
#
# Epoch:[1492/1500], Iteration:[0/15], Loss_G = 3.909642, Loss_D = 0.012275.
#
# Epoch:[1492/1500], Iteration:[2/15], Loss_G = 3.926108, Loss_D = 0.011820.
#
# Epoch:[1492/1500], Iteration:[4/15], Loss_G = 3.852163, Loss_D = 0.011788.
#
# Epoch:[1492/1500], Iteration:[6/15], Loss_G = 4.056770, Loss_D = 0.011994.
#
# Epoch:[1492/1500], Iteration:[8/15], Loss_G = 3.924529, Loss_D = 0.012810.
#
# Epoch:[1492/1500], Iteration:[10/15], Loss_G = 3.796789, Loss_D = 0.011934.
#
# Epoch:[1492/1500], Iteration:[12/15], Loss_G = 3.992489, Loss_D = 0.013852.
#
# Epoch:[1492/1500], Iteration:[14/15], Loss_G = 3.982292, Loss_D = 0.011251.
#
# Epoch:[1492/1500], Loss_G = 3.982292, Loss_D = 0.011251.
#
# Epoch:[1493/1500], Iteration:[0/15], Loss_G = 3.936768, Loss_D = 0.013611.
#
# Epoch:[1493/1500], Iteration:[2/15], Loss_G = 3.946868, Loss_D = 0.011095.
#
# Epoch:[1493/1500], Iteration:[4/15], Loss_G = 3.834717, Loss_D = 0.011853.
#
# Epoch:[1493/1500], Iteration:[6/15], Loss_G = 3.988512, Loss_D = 0.012697.
#
# Epoch:[1493/1500], Iteration:[8/15], Loss_G = 3.948902, Loss_D = 0.011115.
#
# Epoch:[1493/1500], Iteration:[10/15], Loss_G = 3.925592, Loss_D = 0.011516.
#
# Epoch:[1493/1500], Iteration:[12/15], Loss_G = 3.977513, Loss_D = 0.012843.
#
# Epoch:[1493/1500], Iteration:[14/15], Loss_G = 3.954344, Loss_D = 0.011486.
#
# Epoch:[1493/1500], Loss_G = 3.954344, Loss_D = 0.011486.
#
# Epoch:[1494/1500], Iteration:[0/15], Loss_G = 4.023525, Loss_D = 0.013081.
#
# Epoch:[1494/1500], Iteration:[2/15], Loss_G = 3.869989, Loss_D = 0.014403.
#
# Epoch:[1494/1500], Iteration:[4/15], Loss_G = 3.997174, Loss_D = 0.011734.
#
# Epoch:[1494/1500], Iteration:[6/15], Loss_G = 3.963020, Loss_D = 0.013020.
#
# Epoch:[1494/1500], Iteration:[8/15], Loss_G = 3.818768, Loss_D = 0.012637.
#
# Epoch:[1494/1500], Iteration:[10/15], Loss_G = 3.874682, Loss_D = 0.012575.
#
# Epoch:[1494/1500], Iteration:[12/15], Loss_G = 4.002709, Loss_D = 0.012762.
#
# Epoch:[1494/1500], Iteration:[14/15], Loss_G = 4.064745, Loss_D = 0.011047.
#
# Epoch:[1494/1500], Loss_G = 4.064745, Loss_D = 0.011047.
#
# Epoch:[1495/1500], Iteration:[0/15], Loss_G = 4.004723, Loss_D = 0.013030.
#
# Epoch:[1495/1500], Iteration:[2/15], Loss_G = 3.973950, Loss_D = 0.011355.
#
# Epoch:[1495/1500], Iteration:[4/15], Loss_G = 3.806039, Loss_D = 0.011815.
#
# Epoch:[1495/1500], Iteration:[6/15], Loss_G = 3.890748, Loss_D = 0.011678.
#
# Epoch:[1495/1500], Iteration:[8/15], Loss_G = 3.916711, Loss_D = 0.012664.
#
# Epoch:[1495/1500], Iteration:[10/15], Loss_G = 3.922943, Loss_D = 0.015049.
#
# Epoch:[1495/1500], Iteration:[12/15], Loss_G = 3.908051, Loss_D = 0.011737.
#
# Epoch:[1495/1500], Iteration:[14/15], Loss_G = 3.926428, Loss_D = 0.012017.
#
# Epoch:[1495/1500], Loss_G = 3.926428, Loss_D = 0.012017.
#
# Epoch:[1496/1500], Iteration:[0/15], Loss_G = 4.038999, Loss_D = 0.016869.
#
# Epoch:[1496/1500], Iteration:[2/15], Loss_G = 3.906435, Loss_D = 0.011723.
#
# Epoch:[1496/1500], Iteration:[4/15], Loss_G = 3.863307, Loss_D = 0.013916.
#
# Epoch:[1496/1500], Iteration:[6/15], Loss_G = 3.862048, Loss_D = 0.014467.
#
# Epoch:[1496/1500], Iteration:[8/15], Loss_G = 4.062467, Loss_D = 0.012809.
#
# Epoch:[1496/1500], Iteration:[10/15], Loss_G = 4.024212, Loss_D = 0.010794.
#
# Epoch:[1496/1500], Iteration:[12/15], Loss_G = 3.942762, Loss_D = 0.013135.
#
# Epoch:[1496/1500], Iteration:[14/15], Loss_G = 3.971948, Loss_D = 0.015371.
#
# Epoch:[1496/1500], Loss_G = 3.971948, Loss_D = 0.015371.
#
# Epoch:[1497/1500], Iteration:[0/15], Loss_G = 3.909360, Loss_D = 0.012698.
#
# Epoch:[1497/1500], Iteration:[2/15], Loss_G = 3.942226, Loss_D = 0.011334.
#
# Epoch:[1497/1500], Iteration:[4/15], Loss_G = 3.925181, Loss_D = 0.012258.
#
# Epoch:[1497/1500], Iteration:[6/15], Loss_G = 3.852582, Loss_D = 0.013505.
#
# Epoch:[1497/1500], Iteration:[8/15], Loss_G = 3.990005, Loss_D = 0.012817.
#
# Epoch:[1497/1500], Iteration:[10/15], Loss_G = 4.014986, Loss_D = 0.013384.
#
# Epoch:[1497/1500], Iteration:[12/15], Loss_G = 4.041857, Loss_D = 0.011957.
#
# Epoch:[1497/1500], Iteration:[14/15], Loss_G = 4.046125, Loss_D = 0.011775.
#
# Epoch:[1497/1500], Loss_G = 4.046125, Loss_D = 0.011775.
#
# Epoch:[1498/1500], Iteration:[0/15], Loss_G = 3.921126, Loss_D = 0.012484.
#
# Epoch:[1498/1500], Iteration:[2/15], Loss_G = 4.036667, Loss_D = 0.011662.
#
# Epoch:[1498/1500], Iteration:[4/15], Loss_G = 3.818374, Loss_D = 0.011399.
#
# Epoch:[1498/1500], Iteration:[6/15], Loss_G = 3.874473, Loss_D = 0.014426.
#
# Epoch:[1498/1500], Iteration:[8/15], Loss_G = 4.017595, Loss_D = 0.012041.
#
# Epoch:[1498/1500], Iteration:[10/15], Loss_G = 3.989119, Loss_D = 0.011886.
#
# Epoch:[1498/1500], Iteration:[12/15], Loss_G = 4.080605, Loss_D = 0.010774.
#
# Epoch:[1498/1500], Iteration:[14/15], Loss_G = 3.925013, Loss_D = 0.013534.
#
# Epoch:[1498/1500], Loss_G = 3.925013, Loss_D = 0.013534.
#
# Epoch:[1499/1500], Iteration:[0/15], Loss_G = 3.967208, Loss_D = 0.011250.
#
# Epoch:[1499/1500], Iteration:[2/15], Loss_G = 3.993905, Loss_D = 0.011285.
#
# Epoch:[1499/1500], Iteration:[4/15], Loss_G = 3.823969, Loss_D = 0.012393.
#
# Epoch:[1499/1500], Iteration:[6/15], Loss_G = 3.946142, Loss_D = 0.012807.
#
# Epoch:[1499/1500], Iteration:[8/15], Loss_G = 4.008062, Loss_D = 0.011888.
#
# Epoch:[1499/1500], Iteration:[10/15], Loss_G = 3.958835, Loss_D = 0.016946.
#
# Epoch:[1499/1500], Iteration:[12/15], Loss_G = 3.963736, Loss_D = 0.013256.
#
# Epoch:[1499/1500], Iteration:[14/15], Loss_G = 3.840946, Loss_D = 0.012124.
#
# Epoch:[1499/1500], Loss_G = 3.840946, Loss_D = 0.012124.
#
# Epoch:[1500/1500], Iteration:[0/15], Loss_G = 3.955521, Loss_D = 0.014521.
#
# Epoch:[1500/1500], Iteration:[2/15], Loss_G = 3.939886, Loss_D = 0.011550.
#
# Epoch:[1500/1500], Iteration:[4/15], Loss_G = 3.954433, Loss_D = 0.011731.
#
# Epoch:[1500/1500], Iteration:[6/15], Loss_G = 3.955288, Loss_D = 0.011404.
#
# Epoch:[1500/1500], Iteration:[8/15], Loss_G = 4.016188, Loss_D = 0.011964.
#
# Epoch:[1500/1500], Iteration:[10/15], Loss_G = 4.089676, Loss_D = 0.010952.
#
# Epoch:[1500/1500], Iteration:[12/15], Loss_G = 4.002618, Loss_D = 0.012258.
#
# Epoch:[1500/1500], Iteration:[14/15], Loss_G = 4.044854, Loss_D = 0.011260.
#
# Epoch:[1500/1500], Loss_G = 4.044854, Loss_D = 0.011260.

# %%
state_G = {
    'state': G.state_dict(),
    'epoch': 1500,
}
state_D = {
    'state': D.state_dict(),
    'epoch': 1500,
}
torch.save(state_G, 'car_G_1500.pth')
torch.save(state_D, 'car_D_1500.pth')

# %%
# Out:
# 1

# %%
G
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-96e89ba817df> in <module>
# ----> 1 G
#
# NameError: name 'G' is not defined
